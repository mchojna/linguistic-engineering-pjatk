# %% [markdown]
# # Ćwiczenia 3
#  SpaCy -   biblioteka przetwarzania języka.
#
#  Bardziej "profesjonalna", o większych możliwościach
#
# Wymagany jest import biblioteki i odpowiedniego (jednego z wielu) modelu, pobieramy je ze strony spacy

# %%
# !python -m spacy download en_core_web_sm

# %%
# na przykład
import spacy
nlp=spacy.load("en_core_web_sm") #maly model dla angielskiego, są modele różnych rozmiarów dla polskiego
#modele pobieramy ze strony spaCy
#polski model to pl_core_news_sm
# nlp należy do class Language (text processing pipeline) co pozwala aplikowac je na dowolny string
#model wymaga instalacji (download/load)

# %% [markdown]
# W bibliotece spaCy możemy znaleźć narzędzia do wielu etapów analizy językowej.
#
# Zawiera ona tokenizer, tagger, parser, NER i wiele innych, bardzo przydatnych części.
#
# Wszystkie w klasie Language
#
# Spacy rozumie wiele formatów danych np . Doc, Span, Token itd.
#
# Przykładowe narzedzia:
#
# *   tokenizer: dzieli text na tokeny i tworzy obiekt typu Doc
# *   Tagger: przypisuje do tokenów tagi części mowy
# *   Lemmatizer: Redukuje słowo do jego lematu (root form)

# %%
doc=nlp('Hello, world. Natural Language is easy.')

# %% [markdown]
# # Tokenizacja
# Dzieli tekst na części, zwykle pierwsza operacja

# %%
doc1=nlp("Tokenization splits sentence into tokens eg. words.")
print([token.text for token in doc1])
# Out:
# ['Tokenization', 'splits', 'sentence', 'into', 'tokens', 'eg', '.', 'words', '.']

# %% [markdown]
# # Podział na zdania
#
# Segmentator jest częścią DependencyParser.
# Sposób działania znajdziecie Państwo poniżej.

# %%
text="We are learning NLP. This time we learn spaCy!"
doc2=nlp(text)
for sent in doc2.sents:
  print(sent.text)
# Out:
# We are learning NLP.
# This time we learn spaCy!

# %% [markdown]
# # Zadanie 1
# Znajdź tokeny i zdania z tekstu
#
# 'Hello, world. Natural Language is easy.'
#
# Zauważ że to zdanie jest już wczytane
#
#
#
#
# * Wyświetl pierwszy token
#
# *  Wyświetl wszystkie tokeny, każdy w nowej lini
#
# * Wyświetl zdania, każde w nowej lini

# %%
text = 'Hello, world. Natural Language is easy'
doc=nlp(text)

# %% [markdown]
# ### Zadanie 1.1

# %%
doc[0].text
# Out:
# 'Hello'

# %% [markdown]
# ### Zadanie 1.2

# %%
for tok in doc:
    print(tok.text)
# Out:
# Hello
# ,
# world
# .
# Natural
# Language
# is
# easy

# %% [markdown]
# ### Zadanie 1.3

# %%
for tok in doc.sents:
    print(tok)
# Out:
# Hello, world.
# Natural Language is easy

# %% [markdown]
# # Tagowanie części mowy,
#
# dla każdego tokenu przyporządkowuje część mowy

# %%
for token in doc1:
    print('{} - {}'.format(token, token.pos_))
# Out:
# Tokenization - NOUN
# splits - VERB
# sentence - NOUN
# into - ADP
# tokens - PROPN
# eg - PROPN
# . - PROPN
# words - NOUN
# . - PUNCT

# %% [markdown]
# Co robi powyższy kod?

# %% [markdown]
# # Zadanie 2
# Dla każdego wyrazu w zmiennej doc wyświetl odpowiadająca mu część mowy

# %%
# Dla każdego tokenu wyświetl odpowiadającą mu częsć mowy
for token in doc:
    print('{} - {}'.format(token, token.pos_))
# Out:
# Hello - INTJ
# , - PUNCT
# world - NOUN
# . - PUNCT
# Natural - PROPN
# Language - PROPN
# is - AUX
# easy - ADJ

# %% [markdown]
# # Narzędzia dla języka polskiego
# W spaCy znajdują się narzędzia dedykowane językowi polskiemu
#
# Zacznij od instalacji modelu dla języka polskiego:
#
# *pl_core_news_sm*
#
# Wczytaj polski model
#
# # Tagowanie morfosyntaktyczne dla polskiego
#
# Do tagowania można użyć różnych metod, jedną z bardzo dobrze działających jest
# korzystanie z tagsetu NKJP.
#
#  Nasz tagger to słownikowy tagger Morfeusz2 + dezambiguacja za pomocą neuronowego Toyggera (biLSTM)
#
# Każdy token t ma trzy interesujące nas atrybuty:
#
# t.tag_ : klasa gramatyczna według polskiego tagsetu NKJP (http://nkjp.pl/poliqarp/help/ense2.html)
#
# t.pos_ : klasa gramatyczna według międzynarodowego tagsetu UD (mapowana z NKJP)
#
# t._.feats : customowy atrybut odpowiadający cechom morfosyntaktycznym (np. rodzajowi gramatycznemu, lub liczbie), poszczególne wartości cech są oddzielone dwukropkiem

# %%
# !python -m spacy download pl_core_news_sm

# %%
#zadziała tylko jeżeli wczytamy  polski model !!!!

nlp=spacy.load("pl_core_news_sm")

txt = "Nornica prowadzi zmierzchowo-nocny tryb życia, ale wychodzi również za dnia w poszukiwaniu pokarmu."
doc = nlp(txt) # przetworzenie textu przez pipeline, na wyjściu dostajemy iterowalny obiekty klasy Doc, przechowujący tokeny

print("{0:15} {1:8} {2:6}\n".format(".orth_", "NKJP", "UD POS"))
for t in doc:
    print("{0:15} {1:8} {2:6}".format(t.orth_, t.tag_, t.pos_)) # wypisujemy interpretację morfosyntaktyczną każdego tokenu
# Out:
# .orth_          NKJP     UD POS
#
# Nornica         SUBST    NOUN
# prowadzi        FIN      VERB
# zmierzchowo     ADJ      ADJ
# -               ADJ      PUNCT
# nocny           ADJ      ADJ
# tryb            SUBST    NOUN
# życia           GER      NOUN
# ,               INTERP   PUNCT
# ale             CONJ     CCONJ
# wychodzi        FIN      VERB
# również         QUB      PART
# za              PREP     ADP
# dnia            SUBST    NOUN
# w               PREP     ADP
# poszukiwaniu    SUBST    NOUN
# pokarmu         ADJ      NOUN
# .               SUBST    PUNCT

# %% [markdown]
# Czy wynik tagowania wygląda na prawidłowy? Uzasadnij odpowiedź

# %% [markdown]
# # Zadanie 3
#
# Dla tekstu w języku polskim znajdującego sie w pliku 1.txt wykonaj następujące czynności:
#
# *   Podziel tekst na tokeny
# *   Wyświetl ilośc wszystkich wyrazów w tekście
# *   Podziel tekst na zdania
# *   Wyświetl pierwsze zdanie
# *   Wyświetl ilość wszystkich zdan w tekście
# *   Otaguj tekst POS (użyj tagera opartego na morfeuszu lub modelu standardowym, poszukaj w dokumentacji)

# %%
with open("1.txt", "r") as f:
    text = f.read()

# %% [markdown]
# ### Zadanie 3.1

# %%
doc1 = nlp(text)
for sent in doc1.sents:
    print(sent.text)
# Out:
# Natychmiast ujrzał jej zdumione oczy, potem siebie samego w postawie klęczącej i - tak jak niegdyś, podczas deszczowej nocy na balkonie - niby ślimak dotknięty w różki, skurczył się i cofnął w głąb siebie samego.
#
# Baron schylił głowę, jak gdyby się przyglądał swoim butom myślał o czymś.
# Gdzieś tam w toalecie cicho zaskrzypiały drzwi, a na dużej sali czyjeś kroki szybko zdążały w tę stronę.
# Baron ocknął się z zamyślenia - jego czarne, niespokojne oczy na krótko spoczęły na twarzy Romana.
#
# Pikole, przebrani w czyste kaftany i fartuchy, zeszli już na dół.
# Ten i ów zajrzał na korytarz, uchylił drzwi do kawiarni i cofnął się, jak gdyby ujrzał tam coś niemiłego.
# Adaś zdołał ukraść pannom bufetowym kilkanaście talerzyków i zanieść je na swój kredensowy stolik.
# Bardzo go to cieszyło.
#
# Z pokoju wyszła Paulina.
# Poprawiając sobie włosy rozejrzała się po korytarzu i majestatycznym krokiem oddaliła się do swojego mieszkania .
#
# W chwili gdy Palmiak zapiał po raz pierwszy, Grela flirtował z dziewczętami w umywalni.
# Pragnąc się popisać odwagą, podszedł go ryczącego Palmiaka z zamiarem uspokojenia go, ale w tej samej chwili odskoczył od niego i runął na kredens.
#
# Odwróciwszy się omal nie uderzył w brzuch starego Pancera.
# - O, przepraszam! - zawołał patrząc w jego przymrużone oczka.
# - Bartek!
# Przynieś tu panu słomkę do lemoniady, bo zapomniałem - czuł, że szczere przyznanie się do winy zjedna mu starego i odwrócił jego uwagę od gorszych rzeczy - tam przecież jeszcze cztery stoły...
# Stary oparł się o ścianę, jak gdyby zamierzał długo pozostać na tym rewirze.
#
# Ktoś z tamtej strony przytrzymywał drzwi, bufetowiec Bujas mocował się z nimi, próbował to jednego, to drugiego skrzydła, wreszcie dostrzegłszy, że to pikolo Henek tak mocno je trzyma, pchnął z całej siły i wpadł na korytarz.
#
# "Dosyć!
# Ani słowa więcej".
# - Złamał kartkę na pół i wraz z banknotem wsunął ją do koperty, zakleił i zaadresował: "Wny Pan Baron Humaniewski.
# Hotel Pacyfik w/m".
# Po czym bojaźliwie otwarł drzwi hotelowe.
# Hall o tej godzinie był pusty - jedynie portier, gruby, majestatyczny pan w brązowym uniformie ze złoconymi naszywkami, siedział w swej loży i pił czarną kawę, którą mu Roman przed kwadransem przyniósł.
#
# Drugiego dnia, gdy się trochę oswoił z umywalnią, zaczął zwracać uwagę na półmiski znoszone przez pikolaków.
# Już wczoraj zauważył, że parobcy porywali łapczywie kawałki mięsa, więc miał wielką ochotę to samo robić: - No weź sobie - zachęciła go jedna z dziewcząt widząc jego odruch.
#
# Tak trwało do godziny dwunastej, to jest do trzech ważnych i szybko po sobie następujących wydarzeń.
#
# Podskórny uśmiech twarzy Fornalskiego wyciekł na wierzch.
# - No proszę - rzekł do starego rozkładając ręce i wtulając głowę między barki, jakby zgorszony beznadziejną głupotą Boryczki - wyraźnie słyszał, jak gość zamawiał Martella z trzema gwiazdkami...
#
# Co pewien czas panny wymyślały takie wieloznaczne słowa i ruchy wzbudzające śmiech i mające na celu skrócenie skomplikowanych określeń: "jesteś pan ciężkomyślący" - w odniesieniu do Janika, lub: "jesteś pan nieprzytomny" - w odniesieniu do Kantary.
# Niedawno temu posługiwały się słówkami "był" i "biedny" - pierwsze wymawiano krótko, drugie z politowaniem i kiwaniem głowy.
#
# Zdawał sobie jednak sprawę, że będzie mu trudno to zrobić, albowiem panowie z pta znali ceny potraw lepiej niż kelnerzy.
#
# Tymczasem w bufecie panna Tola czyściła koszyki do chleba.
# Od czasu do czasu wycierała palce i sięgała do kieszeni fartucha, wyjmowała kruche ciastko, ugryzła je i znów chowała do kieszeni.
#
# Tymczasem na dole zaczęło się kotłować.
# Do gabinetu restauracyjnego wpadło kilkanaście osób - spieszyło im się bardzo, żądali natychmiastowej obsługi.
# Grela zesunął stoły, Julka wysłał do bufetu po jarzębiak i masło, sam udał się po zimne zakąski.
# Okazało się, że wózek i wszystkie półmiski z rybami zabrano na trójkę do Teodora.
# Teodor nie pozwolił sobie ich odebrać.
#
# Boryczko rozejrzał się szybko po rewirze - z zadowoleniem stwierdził, że wśród kilkunastu par oczu zwróconych w jego stronę nie było tych niebieskich - dyskretnie skryły się za teczką tygodnika.
#
# "Zbój Madej"
# też coś wiedział.
# Z początku udawał, że się tym nie interesuje, zachowywał się wobec Romana tak jak zawsze: pociągał go za rękaw i powtarzał zamówienia lub prosił, by zechciał "rzucić okiem" na jego rewir.
# Ale raz, gdy się zeszli na rewirze i nic nie mieli do roboty, Robak pogłaskał swoją łysinę i zaczął namiętnie gryźć dolną wargę - znak, że ma coś ważnego do powiedzenia.
#
# Chwila milczenia.
# Romek uniósł się na łokciu, zaczął nerwowo mrugać okiem, wreszcie rzekł: - Ja myślę, że więcej, bo widzi pan, z tym okiem coś nie w porządku.
#
# Kierownik Stec wrócił z restauracji od Fornalskiego, sprawdził kasę, czy jest skręcona, schował kwity i zamknął szufladę.
# Przez chwilę myślał o czymś, wreszcie kiwnął głową, powiedział pannie Toli dobranoc i uśmiechając się sam do siebie, poszedł do garderoby po futro.
# Ubrawszy się, wstąpił do pokoju damskiego.
#
# Ale budzik jest dobry, co?
# Ilem razy go rzucał na podłogę i nic..., trzyma się kupy.
# Dobra marka, Jaz.
#
# I oto w tej chwili pociąg z Helą mknął przez zaśnieżone pola, a Roman szedł ostrożnie ulicą i unikał potrąceń, by nie uronić przedwcześnie ani odrobiny płynnej żałości, zapełniającej go aż po krtań i oczy.
#
# Gdzieś tam na "Sybirze", niby pająk w sieci ukryty, świdruje kelnerów wzrok starego Pancera - czują go nawet ci, w drugim końcu kawiarni, za czwartą ścianą z cegły.
# Niechby się już wyniósł stąd, a zrobiłoby się dobrze jak po wyrwaniu chorego zęba.
#
# Nie, "Kucyk" nie miał powodzenia wśród personelu, a najmniej u kelnerów.
# Jego motorkowo-pęcherzykowa ruchliwość i "cudeńka", jakie pokazywał przed gośćmi, budziły raczej wesołość niż podziw.
# Zrażony do kelnerów, zapędzał się do kuchni, ale tam znów gruby, wąsaty szef Balcer pokazywał mu kły: - Co pan tu chce, do rondli zaglądać i uczyć, jak sosy przyprawiać!?
#
# Stary Pancer, z rękami w kieszeniach spodni, stał oparty o biurko.
# Krótkie nogi założone jedna na drugą, dolna warga wysunięta, oczka zmrużone i patrzące tak samo jak o godzinie dwunastej spośród kolorowych wstęg i baloników koło drzwi kuchennych.
#
# Gdzieś tam w kłębach pary dojrzał i zapamiętał dziewczęcą twarz pomocnicy kawiarki, i znów oczy, tym razem bure, figlarne i wyłupiaste jak u wiewiórki.
# Czując, że mu gorąca fala zalewa policzki, niezgrabnie postawił szklankę na półce i nie widząc nic wycofał się na dużą salę.
# Szedł na oślep w kierunku swojego rewiru, szedł coraz wolniej, wreszcie potknął się o krzesło i stanął w miejscu.
#
# Na korytarzu ozwały się czyjeś kroki - Henek podniósł wskazujący palec do góry: - Ty, ja cię proszę, Adamowi nie mów nic, ona prosiła... i w ogóle nikomu...
#
# I znowu nic.
# Czarne, migotliwe oczy wpatrzyły się w Boryczkę, pyzata twarz i zadarty nos jakby napęczniały od krwi.
# "Smieszny jest ten baron i podobny do kogoś... aha, do parobka Wicka.
# A może to naprawdę Wicek, tylko przebrany i bogaty?
# E, nie, Wicek młodszy od niego.
# " - Panie baronie, "London News" jest świeży - otwarł tytułową stronicą tygodnika.
#
# O godzinie ósmej wszyscy kelnerzy i pikole byli już na korytarzu kuchennym...
# Palmiak podchmielony i wesoły wychylił głowę przez okno: - Panowie!!! - wrzasnął - bufet wydawać!
#
# Henek opiekuńczo krążył w pobliżu.
# - Umiesz markować na kasie?
#
# Henek rozejrzał się wokoło i pewny, że nikt nie patrzy, zaczął tupać o podłogę i krzyczeć chrapliwym głosem: - Psiakrew!
# Smarkacz! Bijesz!
# Na kasie!
# Nie pamiętasz!
# Co robisz!
# Psiakrew!
# Smarkacz!
#
# Wszystko wydało mu się pozbawione tajemniczości, ograniczone czasem i przestrzenią, objęte umysłem i nieskomplikowane.
# Szedłby o zakład, że da radę obsłużyć wszystkie rewiry w kawiarni i jeszcze znajdzie trochę czasu na wypalenie papierosa.
# "Oni wszyscy są dzisiaj mętni - myślał patrząc na kierownika i kelnerów uwijających się po kawiarni jak mrówki w zburzonym mrowisku - przydałby się im jaki zastrzyk na uspokojenie".
#
# Roman klęczał na posadzce i szukał pieniędzy, które mu podczas inkasowania wypadły z ręki.
# Chodził tak na raczkach po całym rewirze, zaglądał pod foteliki i kanapy, ściereczka zwisała mu z kieszeni, włosy opadły na czoło - musiał je co chwila zarzucać w tył.
#
# On jest teraz na mnie zły, bo myśli, że ja mu to naumyślnie zrobiłem.
# Jakże bym ja śmiał...
#
# Około jedenastej śniadania się kończyły, zamawiano czarne kawy, herbaty i kapucyny.
# "Sybir" ział pustką - Wieliński i Bandera patrzyli przez okno na ulicę i wzrokiem odprowadzali przechodniów lub gapili się na gzymsy przyprószone śniegiem i ołowiany skrawek nieba, zabudowany kominami przyległych kamienic i zasiekami anten radiowych, sterczących wichrowato jak drewniane krzyże na starym cmentarzu .
#
# Roman dźwignął nowy ładunek podwieczorków i ruszył na salę.
# Tuż przed nim szedł Kantara - trzymał w rękach tak dużo tacek, że aby zrównoważyć ich ciężar, przechylił się w tył i łokieć oparł na brzuchu.
# Chcąc go pośpieszyć Roman krzyknął mu nad uchem: "prędzej!" - Kantara obejrzał się.
#
# Nikt się na to nie odezwał - Bandera zna się na tym lepiej od innych.
# Kiedyś powiedział tak: "I cóż z tego, że ci wszyscy filozofowie grzebią w książkach i tak dużo myślą?
# Co dokonali?
# Nic.
# A najzabawniejsze to, że zawsze wracają tam, skąd wyszli".
#
# Wieczorami spacerował wzdłuż kawiarni i zaglądał w okna pod firanki.
# Do interesu przychodził o szóstej rano, stawał w garderobie kawiarnianej, wyjmował zegarek i notes i zapisywał tych, którzy się spóźniali - już pierwszego dnia trafikantce i paru kelnerom nałożył grzywny po pięć złotych na cele dobroczynne.
#
# Mimo to Roman zbliżył się do stołu, oparł się o czyjeś krzesło i płaczliwym głosem zapytał: - Jaśnie pan redaktor życzył sobie "Kuriera"?
# Niech mi jaśnie pan wierzy, że nie ma ani jednego, wszystkie są zajęte, jak Boga kocham, że zajęte.
#
# Istotnie, w damskim pokoju aż syczało.
# Roman wpadł na swój rewir jak w nagalwanizowane pole.
# Ze wszech stron wołano płacić, trzymane w palcach banknoty powiewały w powietrzu, monety rzucane na marmur wpadały w kołujący, jednostajnie przyspieszony ruch lub toczyły się na brzeg stołu i tam, przytrzymane gwałtownym skokiem ręki, wydawały krótki fałszywy dźwięk .
#
# "Zostawiłam płaszcz przy piecu, żeby wysechł, i cały przód się przyżelił.
# Nie gniewaj się, bardzo cię proszę, przyślij mi dwadzieścia złotych, ja ci je oddam po pierwszym".
# Posłał jej dwadzieścia złotych, ale to go tak rozgoryczyło, że w tym samym dniu zapłacił czynsz, podatek i składki miesięczne do Związku, praczce dał zaległe piętnaście złotych i krawcowi spłacił dwie ostatnie raty za ubranie.

# %% [markdown]
# ### Zadanie 3.2

# %%
len(doc1)
# Out:
# 2035

# %% [markdown]
# ### Zadanie 3.3

# %%
sentens = [tok.text for tok in doc1.sents]
print(sentens)
# Out:
# ['Natychmiast ujrzał jej zdumione oczy, potem siebie samego w postawie klęczącej i - tak jak niegdyś, podczas deszczowej nocy na balkonie - niby ślimak dotknięty w różki, skurczył się i cofnął w głąb siebie samego.\n', 'Baron schylił głowę, jak gdyby się przyglądał swoim butom myślał o czymś.', 'Gdzieś tam w toalecie cicho zaskrzypiały drzwi, a na dużej sali czyjeś kroki szybko zdążały w tę stronę.', 'Baron ocknął się z zamyślenia - jego czarne, niespokojne oczy na krótko spoczęły na twarzy Romana.\n', 'Pikole, przebrani w czyste kaftany i fartuchy, zeszli już na dół.', 'Ten i ów zajrzał na korytarz, uchylił drzwi do kawiarni i cofnął się, jak gdyby ujrzał tam coś niemiłego.', 'Adaś zdołał ukraść pannom bufetowym kilkanaście talerzyków i zanieść je na swój kredensowy stolik.', 'Bardzo go to cieszyło.\n', 'Z pokoju wyszła Paulina.', 'Poprawiając sobie włosy rozejrzała się po korytarzu i majestatycznym krokiem oddaliła się do swojego mieszkania .\n', 'W chwili gdy Palmiak zapiał po raz pierwszy, Grela flirtował z dziewczętami w umywalni.', 'Pragnąc się popisać odwagą, podszedł go ryczącego Palmiaka z zamiarem uspokojenia go, ale w tej samej chwili odskoczył od niego i runął na kredens.\n', 'Odwróciwszy się omal nie uderzył w brzuch starego Pancera.', '- O, przepraszam! - zawołał patrząc w jego przymrużone oczka.', '- Bartek!', 'Przynieś tu panu słomkę do lemoniady, bo zapomniałem - czuł, że szczere przyznanie się do winy zjedna mu starego i odwrócił jego uwagę od gorszych rzeczy - tam przecież jeszcze cztery stoły...', 'Stary oparł się o ścianę, jak gdyby zamierzał długo pozostać na tym rewirze.\n', 'Ktoś z tamtej strony przytrzymywał drzwi, bufetowiec Bujas mocował się z nimi, próbował to jednego, to drugiego skrzydła, wreszcie dostrzegłszy, że to pikolo Henek tak mocno je trzyma, pchnął z całej siły i wpadł na korytarz.\n', '"Dosyć!', 'Ani słowa więcej".', '- Złamał kartkę na pół i wraz z banknotem wsunął ją do koperty, zakleił i zaadresował: "Wny Pan Baron Humaniewski.', 'Hotel Pacyfik w/m".', 'Po czym bojaźliwie otwarł drzwi hotelowe.', 'Hall o tej godzinie był pusty - jedynie portier, gruby, majestatyczny pan w brązowym uniformie ze złoconymi naszywkami, siedział w swej loży i pił czarną kawę, którą mu Roman przed kwadransem przyniósł.\n', 'Drugiego dnia, gdy się trochę oswoił z umywalnią, zaczął zwracać uwagę na półmiski znoszone przez pikolaków.', 'Już wczoraj zauważył, że parobcy porywali łapczywie kawałki mięsa, więc miał wielką ochotę to samo robić: - No weź sobie - zachęciła go jedna z dziewcząt widząc jego odruch.\n', 'Tak trwało do godziny dwunastej, to jest do trzech ważnych i szybko po sobie następujących wydarzeń.\n', 'Podskórny uśmiech twarzy Fornalskiego wyciekł na wierzch.', '- No proszę - rzekł do starego rozkładając ręce i wtulając głowę między barki, jakby zgorszony beznadziejną głupotą Boryczki - wyraźnie słyszał, jak gość zamawiał Martella z trzema gwiazdkami...\n', 'Co pewien czas panny wymyślały takie wieloznaczne słowa i ruchy wzbudzające śmiech i mające na celu skrócenie skomplikowanych określeń: "jesteś pan ciężkomyślący" - w odniesieniu do Janika, lub: "jesteś pan nieprzytomny" - w odniesieniu do Kantary.', 'Niedawno temu posługiwały się słówkami "był" i "biedny" - pierwsze wymawiano krótko, drugie z politowaniem i kiwaniem głowy.\n', 'Zdawał sobie jednak sprawę, że będzie mu trudno to zrobić, albowiem panowie z pta znali ceny potraw lepiej niż kelnerzy.\n', 'Tymczasem w bufecie panna Tola czyściła koszyki do chleba.', 'Od czasu do czasu wycierała palce i sięgała do kieszeni fartucha, wyjmowała kruche ciastko, ugryzła je i znów chowała do kieszeni.\n', 'Tymczasem na dole zaczęło się kotłować.', 'Do gabinetu restauracyjnego wpadło kilkanaście osób - spieszyło im się bardzo, żądali natychmiastowej obsługi.', 'Grela zesunął stoły, Julka wysłał do bufetu po jarzębiak i masło, sam udał się po zimne zakąski.', 'Okazało się, że wózek i wszystkie półmiski z rybami zabrano na trójkę do Teodora.', 'Teodor nie ...

# %% [markdown]
# ### Zadanie 3.4

# %%
sentens[0]
# Out:
# 'Natychmiast ujrzał jej zdumione oczy, potem siebie samego w postawie klęczącej i - tak jak niegdyś, podczas deszczowej nocy na balkonie - niby ślimak dotknięty w różki, skurczył się i cofnął w głąb siebie samego.\n'

# %% [markdown]
# ### Zadanie 3.5

# %%
len(sentens)
# Out:
# 108

# %% [markdown]
# ### Zadanie 3.6

# %%
print("{0:15} {1:8} {2:6}\n".format(".orth_", "NKJP", "UD POS"))
for t in doc1:
    print("{0:15} {1:8} {2:6}".format(t.orth_, t.tag_, t.pos_) )
# Out:
# .orth_          NKJP     UD POS
#
# Natychmiast     ADV      ADV
# ujrzał          PRAET    VERB
# jej             PPRON3   PRON
# zdumione        ADJ      ADJ
# oczy            SUBST    NOUN
# ,               INTERP   PUNCT
# potem           ADV      ADV
# siebie          SIEBIE   PRON
# samego          ADJ      ADJ
# w               PREP     ADP
# postawie        SUBST    NOUN
# klęczącej       ADJ      ADJ
# i               CONJ     CCONJ
# -               INTERP   PUNCT
# tak             ADV      ADV
# jak             ADV      SCONJ
# niegdyś         SUBST    ADV
# ,               INTERP   PUNCT
# podczas         PREP     ADP
# deszczowej      ADJ      ADJ
# nocy            SUBST    NOUN
# na              PREP     ADP
# balkonie        SUBST    NOUN
# -               INTERP   PUNCT
# niby            QUB      SCONJ
# ślimak          SUBST    NOUN
# dotknięty       PPAS     ADJ
# w               PREP     ADP
# różki           SUBST    NOUN
# ,               SUBST    PUNCT
# skurczył        PRAET    VERB
# się             QUB      PRON
# i               CONJ     CCONJ
# cofnął          PRAET    VERB
# w               PREP     ADP
# głąb            SUBST    NOUN
# siebie          SIEBIE   PRON
# samego          SUBST    ADJ
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Baron           SUBST    NOUN
# schylił         PRAET    VERB
# głowę           SUBST    NOUN
# ,               INTERP   PUNCT
# jak             QUB      SCONJ
# gdyby           QUB      SCONJ
# się             QUB      PRON
# przyglądał      PRAET    VERB
# swoim           ADJ      DET
# butom           SUBST    NOUN
# myślał          PRAET    VERB
# o               PREP     ADP
# czymś           SUBST    PRON
# .               INTERP   PUNCT
# Gdzieś          ADV      ADV
# tam             ADV      ADV
# w               PREP     ADP
# toalecie        SUBST    NOUN
# cicho           ADV      ADV
# zaskrzypiały    PRAET    VERB
# drzwi           SUBST    NOUN
# ,               SUBST    PUNCT
# a               CONJ     CCONJ
# na              PREP     ADP
# dużej           ADJ      ADJ
# sali            SUBST    NOUN
# czyjeś          ADJ      DET
# kroki           SUBST    NOUN
# szybko          ADV      ADV
# zdążały         PRAET    VERB
# w               PREP     ADP
# tę              ADJ      DET
# stronę          SUBST    NOUN
# .               INTERP   PUNCT
# Baron           SUBST    NOUN
# ocknął          PRAET    VERB
# się             QUB      PRON
# z               PREP     ADP
# zamyślenia      SUBST    NOUN
# -               INTERP   PUNCT
# jego            PPRON3   PRON
# czarne          ADJ      ADJ
# ,               ADJ      PUNCT
# niespokojne     ADJ      ADJ
# oczy            SUBST    NOUN
# na              PREP     ADP
# krótko          ADV      ADV
# spoczęły        PRAET    VERB
# na              PREP     ADP
# twarzy          SUBST    NOUN
# Romana          SUBST    PROPN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Pikole          SUBST    NOUN
# ,               SUBST    PUNCT
# przebrani       ADJ      ADJ
# w               PREP     ADP
# czyste          ADJ      ADJ
# kaftany         SUBST    NOUN
# i               CONJ     CCONJ
# fartuchy        SUBST    NOUN
# ,               INTERP   PUNCT
# zeszli          PRAET    VERB
# już             QUB      PART
# na              PREP     ADP
# dół             SUBST    NOUN
# .               SUBST    PUNCT
# Ten             ADJ      DET
# i               CONJ     CCONJ
# ów              ADJ      DET
# zajrzał         PRAET    VERB
# na              PREP     ADP
# korytarz        SUBST    NOUN
# ,               INTERP   PUNCT
# uchylił         PRAET    VERB
# drzwi           SUBST    NOUN
# do              PREP     ADP
# kawiarni        SUBST    NOUN
# i               CONJ     CCONJ
# cofnął          PRAET    VERB
# się             QUB      PRON
# ,               INTERP   PUNCT
# jak             ADV      SCONJ
# gdyby           QUB      PART
# ujrzał          PRAET    VERB
# tam             ADV      ADV
# coś             SUBST    PRON
# niemiłego       SUBST    ADJ
# .               SUBST    PUNCT
# Adaś            SUBST    PROPN
# zdołał          PRAET    VERB
# ukraść          INF      VERB
# pannom          SUBST    NOUN
# bufetowym       ADJ      ADJ
# kilkanaście     NUM      DET
# talerzyków      SUBST    NOUN
# i               CONJ     CCONJ
# zanieść         INF      VERB
# je              PPRON3   PRON
# na              PREP     ADP
# swój            ADJ      DET
# kredensowy      ADJ      ADJ
# stolik          SUBST    NOUN
# .               INTERP   PUNCT
# Bardzo          ADV      ADV
# go              PPRON3   PRON
# to              SUBST    PRON
# cieszyło        SUBST    VERB
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Z               PREP     ADP
# pokoju          SUBST    NOUN
# wyszła          PRAET    VERB
# Paulina         SUBST    PROPN
# .               INTERP   PUNCT
# Poprawiając     PCON     VERB
# sobie           SIEBIE   PRON
# włosy           SUBST    NOUN
# rozejrzała      PRAET    VERB
# się             QUB      PRON
# po              PREP     ADP
# korytarzu       SUBST    NOUN
# i               CONJ     CCONJ
# majestatycznym  ADJ      ADJ
# krokiem         SUBST    NOUN
# oddaliła        PRAET    VERB
# się             QUB      PRON
# do              PREP     ADP
# swojego         ADJ      DET
# mieszkania      SUBST    NOUN
# .               INTERP   PUNCT
#
#                _SP      SPACE
# W               PREP     ADP
# chwili          SUBST    NOUN
# gdy             ADV      ADV
# Palmiak         SUBST    PROPN
# zapiał          PRAET    VERB
# po              PREP     ADP
# raz             SUBST    NOUN
# pierwszy        SUBST    ADJ
# ,               SUBST    PUNCT
# Grela           SUBST    PROPN
# flirtował       PRAET    VERB
# z               PREP     ADP
# dziewczętami    SUBST    NOUN
# w               PREP     ADP
# umywalni        SUBST    NOUN
# .               INTERP   PUNCT
# Pragnąc         PCON     VERB
# się             QUB      PRON
# popisać         INF      VERB
# odwagą          SUBST    NOUN
# ,               INTERP   PUNCT
# podszedł        PRAET    VERB
# go              PPRON3   PRON
# ryczącego       PACT     ADJ
# Palmiaka        SUBST    PROPN
# z               PREP     ADP
# zamiarem        SUBST    NOUN
# uspokojenia     GER      NOUN
# go              SUBST    PRON
# ,               INTERP   PUNCT
# ale             CONJ     CCONJ
# w               PREP     ADP
# tej             ADJ      DET
# samej           ADJ      ADJ
# chwili          SUBST    NOUN
# odskoczył       PRAET    VERB
# od              PREP     ADP
# niego           PPRON3   PRON
# i               CONJ     CCONJ
# runął           PRAET    VERB
# na              PREP     ADP
# kredens         SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Odwróciwszy     PANT     VERB
# się             QUB      PRON
# omal            ADV      ADV
# nie             QUB      PART
# uderzył         PRAET    VERB
# w               PREP     ADP
# brzuch          SUBST    NOUN
# starego         ADJ      ADJ
# Pancera         SUBST    PROPN
# .               SUBST    PUNCT
# -               INTERP   PUNCT
# O               INTERJ   INTJ
# ,               INTERP   PUNCT
# przepraszam     SUBST    VERB
# !               INTERP   PUNCT
# -               INTERP   PUNCT
# zawołał         PRAET    VERB
# patrząc         PCON     VERB
# w               PREP     ADP
# jego            PPRON3   PRON
# przymrużone     PPAS     ADJ
# oczka           SUBST    NOUN
# .               SUBST    PUNCT
# -               INTERP   PUNCT
# Bartek          SUBST    PROPN
# !               INTERP   PUNCT
# Przynieś        IMPT     VERB
# tu              ADV      ADV
# panu            SUBST    NOUN
# słomkę          SUBST    NOUN
# do              PREP     ADP
# lemoniady       SUBST    NOUN
# ,               INTERP   PUNCT
# bo              COMP     SCONJ
# zapomniałem     SUBST    VERB
# -               INTERP   PUNCT
# czuł            SUBST    VERB
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# szczere         ADJ      ADJ
# przyznanie      GER      NOUN
# się             QUB      PRON
# do              PREP     ADP
# winy            SUBST    NOUN
# zjedna          FIN      VERB
# mu              PPRON3   PRON
# starego         SUBST    ADJ
# i               CONJ     CCONJ
# odwrócił        PRAET    VERB
# jego            PPRON3   PRON
# uwagę           SUBST    NOUN
# od              PREP     ADP
# gorszych        ADJ      ADJ
# rzeczy          SUBST    NOUN
# -               INTERP   PUNCT
# tam             ADV      ADV
# przecież        QUB      PART
# jeszcze         QUB      PART
# cztery          NUM      NUM
# stoły           SUBST    NOUN
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               INTERP   PUNCT
# Stary           SUBST    NOUN
# oparł           PRAET    VERB
# się             QUB      PRON
# o               PREP     ADP
# ścianę          SUBST    NOUN
# ,               INTERP   PUNCT
# jak             QUB      SCONJ
# gdyby           QUB      PART
# zamierzał       PRAET    VERB
# długo           ADV      ADV
# pozostać        INF      VERB
# na              PREP     ADP
# tym             SUBST    DET
# rewirze         SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Ktoś            SUBST    PRON
# z               PREP     ADP
# tamtej          ADJ      DET
# strony          SUBST    NOUN
# przytrzymywał   PRAET    VERB
# drzwi           SUBST    NOUN
# ,               SUBST    PUNCT
# bufetowiec      SUBST    NOUN
# Bujas           SUBST    PROPN
# mocował         PRAET    VERB
# się             QUB      PRON
# z               PREP     ADP
# nimi            SUBST    PRON
# ,               INTERP   PUNCT
# próbował        PRAET    VERB
# to              SUBST    PRON
# jednego         SUBST    ADJ
# ,               SUBST    PUNCT
# to              CONJ     SCONJ
# drugiego        ADJ      ADJ
# skrzydła        SUBST    NOUN
# ,               INTERP   PUNCT
# wreszcie        QUB      PART
# dostrzegłszy    _SP      ADJ
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# to              PRED     AUX
# pikolo          SUBST    NOUN
# Henek           SUBST    PROPN
# tak             ADV      ADV
# mocno           ADV      ADV
# je              PPRON3   PRON
# trzyma          _SP      VERB
# ,               INTERP   PUNCT
# pchnął          PRAET    VERB
# z               PREP     ADP
# całej           ADJ      ADJ
# siły            SUBST    NOUN
# i               CONJ     CCONJ
# wpadł           PRAET    VERB
# na              PREP     ADP
# korytarz        SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# "               INTERP   PUNCT
# Dosyć           SUBST    PART
# !               INTERP   PUNCT
# Ani             QUB      PART
# słowa           SUBST    NOUN
# więcej          NUM      DET
# "               SUBST    PUNCT
# .               INTERP   PUNCT
# -               INTERP   PUNCT
# Złamał          PRAET    VERB
# kartkę          SUBST    NOUN
# na              PREP     ADP
# pół             SUBST    NUM
# i               CONJ     CCONJ
# wraz            ADV      ADV
# z               PREP     ADP
# banknotem       SUBST    NOUN
# wsunął          PRAET    VERB
# ją              PPRON3   PRON
# do              PREP     ADP
# koperty         SUBST    NOUN
# ,               INTERP   PUNCT
# zakleił         PRAET    VERB
# i               CONJ     CCONJ
# zaadresował     SUBST    VERB
# :               INTERP   PUNCT
# "               INTERP   PUNCT
# Wny             BREV     PROPN
# Pan             SUBST    NOUN
# Baron           SUBST    PROPN
# Humaniewski     SUBST    PROPN
# .               INTERP   PUNCT
# Hotel           SUBST    NOUN
# Pacyfik         SUBST    PROPN
# w               BREV     ADP
# /               BREV     PROPN
# m               SUBST    X
# "               BREV     PUNCT
# .               INTERP   PUNCT
# Po              PREP     ADP
# czym            SUBST    PRON
# bojaźliwie      ADV      NOUN
# otwarł          PRAET    VERB
# drzwi           SUBST    NOUN
# hotelowe        ADJ      ADJ
# .               SUBST    PUNCT
# Hall            SUBST    NOUN
# o               PREP     ADP
# tej             ADJ      DET
# godzinie        SUBST    NOUN
# był             PRAET    AUX
# pusty           ADJ      ADJ
# -               INTERP   PUNCT
# jedynie         QUB      PART
# portier         SUBST    NOUN
# ,               SUBST    PUNCT
# gruby           SUBST    ADJ
# ,               ADJ      PUNCT
# majestatyczny   ADJ      ADJ
# pan             SUBST    NOUN
# w               PREP     ADP
# brązowym        ADJ      ADJ
# uniformie       SUBST    NOUN
# ze              PREP     ADP
# złoconymi       ADJ      ADJ
# naszywkami      SUBST    NOUN
# ,               SUBST    PUNCT
# siedział        PRAET    VERB
# w               PREP     ADP
# swej            ADJ      DET
# loży            SUBST    NOUN
# i               CONJ     CCONJ
# pił             PRAET    VERB
# czarną          ADJ      ADJ
# kawę            SUBST    NOUN
# ,               INTERP   PUNCT
# którą           ADJ      DET
# mu              PPRON3   PRON
# Roman           SUBST    PROPN
# przed           PREP     ADP
# kwadransem      SUBST    NOUN
# przyniósł       SUBST    VERB
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Drugiego        ADJ      ADJ
# dnia            SUBST    NOUN
# ,               INTERP   PUNCT
# gdy             ADV      ADV
# się             QUB      PRON
# trochę          ADV      ADV
# oswoił          PRAET    VERB
# z               PREP     ADP
# umywalnią       SUBST    NOUN
# ,               INTERP   PUNCT
# zaczął          PRAET    VERB
# zwracać         INF      VERB
# uwagę           SUBST    NOUN
# na              PREP     ADP
# półmiski        SUBST    NOUN
# znoszone        PPAS     ADJ
# przez           PREP     ADP
# pikolaków       SUBST    NOUN
# .               INTERP   PUNCT
# Już             QUB      PART
# wczoraj         ADV      ADV
# zauważył        PRAET    VERB
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# parobcy         SUBST    NOUN
# porywali        PRAET    VERB
# łapczywie       ADV      ADV
# kawałki         SUBST    NOUN
# mięsa           SUBST    NOUN
# ,               SUBST    PUNCT
# więc            CONJ     SCONJ
# miał            PRAET    VERB
# wielką          ADJ      ADJ
# ochotę          SUBST    NOUN
# to              SUBST    PRON
# samo            ADJ      ADJ
# robić           SUBST    VERB
# :               INTERP   PUNCT
# -               INTERP   PUNCT
# No              QUB      PART
# weź             IMPT     VERB
# sobie           SIEBIE   PRON
# -               INTERP   PUNCT
# zachęciła       PRAET    VERB
# go              PPRON3   PRON
# jedna           ADJ      ADJ
# z               PREP     ADP
# dziewcząt       SUBST    NOUN
# widząc          PCON     VERB
# jego            PPRON3   PRON
# odruch          SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Tak             ADV      ADV
# trwało          PRAET    VERB
# do              PREP     ADP
# godziny         SUBST    NOUN
# dwunastej       SUBST    ADJ
# ,               SUBST    PUNCT
# to              SUBST    AUX
# jest            FIN      VERB
# do              PREP     ADP
# trzech          NUM      NUM
# ważnych         ADJ      ADJ
# i               CONJ     CCONJ
# szybko          ADV      ADV
# po              PREP     ADP
# sobie           SIEBIE   PRON
# następujących   PACT     ADJ
# wydarzeń        SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Podskórny       ADJ      ADJ
# uśmiech         SUBST    NOUN
# twarzy          SUBST    NOUN
# Fornalskiego    SUBST    PROPN
# wyciekł         PRAET    VERB
# na              PREP     ADP
# wierzch         SUBST    NOUN
# .               SUBST    PUNCT
# -               INTERP   PUNCT
# No              QUB      PART
# proszę          FIN      VERB
# -               INTERP   PUNCT
# rzekł           PRAET    VERB
# do              PREP     ADP
# starego         SUBST    NOUN
# rozkładając     PCON     VERB
# ręce            SUBST    NOUN
# i               CONJ     CCONJ
# wtulając        PCON     VERB
# głowę           SUBST    NOUN
# między          PREP     ADP
# barki           SUBST    NOUN
# ,               INTERP   PUNCT
# jakby           QUB      SCONJ
# zgorszony       ADJ      ADJ
# beznadziejną    ADJ      ADJ
# głupotą         SUBST    NOUN
# Boryczki        SUBST    PROPN
# -               INTERP   PUNCT
# wyraźnie        ADV      ADV
# słyszał         INTERP   VERB
# ,               INTERP   PUNCT
# jak             ADV      SCONJ
# gość            SUBST    NOUN
# zamawiał        PRAET    VERB
# Martella        SUBST    PROPN
# z               PREP     ADP
# trzema          NUM      NUM
# gwiazdkami      SUBST    NOUN
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Co              PREP     PRON
# pewien          ADJ      DET
# czas            SUBST    NOUN
# panny           SUBST    NOUN
# wymyślały       PRAET    VERB
# takie           ADJ      DET
# wieloznaczne    ADJ      ADJ
# słowa           SUBST    NOUN
# i               CONJ     CCONJ
# ruchy           SUBST    NOUN
# wzbudzające     PACT     ADJ
# śmiech          SUBST    NOUN
# i               CONJ     CCONJ
# mające          PACT     ADJ
# na              PREP     ADP
# celu            SUBST    NOUN
# skrócenie       GER      NOUN
# skomplikowanych ADJ      ADJ
# określeń        SUBST    NOUN
# :               SUBST    PUNCT
# "               INTERP   PUNCT
# jesteś          FIN      AUX
# pan             SUBST    NOUN
# ciężkomyślący   SUBST    ADJ
# "               INTERP   PUNCT
# -               INTERP   PUNCT
# w               PREP     ADP
# odniesieniu     SUBST    NOUN
# do              PREP     ADP
# Janika          SUBST    NOUN
# ,               INTERP   PUNCT
# lub             SUBST    CCONJ
# :               SUBST    PUNCT
# "               INTERP   PUNCT
# jesteś          FIN      AUX
# pan             SUBST    NOUN
# nieprzytomny    SUBST    ADJ
# "               INTERP   PUNCT
# -               INTERP   PUNCT
# w               PREP     ADP
# odniesieniu     SUBST    NOUN
# do              PREP     ADP
# Kantary         SUBST    PROPN
# .               INTERP   PUNCT
# Niedawno        ADV      ADV
# temu            PREP     ADP
# posługiwały     PRAET    VERB
# się             QUB      PRON
# słówkami        SUBST    NOUN
# "               INTERP   PUNCT
# był             SUBST    VERB
# "               INTERP   PUNCT
# i               CONJ     CCONJ
# "               INTERP   PUNCT
# biedny          SUBST    ADJ
# "               INTERP   PUNCT
# -               INTERP   PUNCT
# pierwsze        ADJ      ADJ
# wymawiano       IMPS     VERB
# krótko          ADJ      ADV
# ,               INTERP   PUNCT
# drugie          ADJ      ADJ
# z               PREP     ADP
# politowaniem    SUBST    NOUN
# i               CONJ     CCONJ
# kiwaniem        SUBST    NOUN
# głowy           SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Zdawał          PRAET    VERB
# sobie           SIEBIE   PRON
# jednak          CONJ     CCONJ
# sprawę          SUBST    NOUN
# ,               SUBST    PUNCT
# że              COMP     SCONJ
# będzie          BEDZIE   AUX
# mu              PPRON3   PRON
# trudno          ADV      ADV
# to              SUBST    PRON
# zrobić          INF      VERB
# ,               INTERP   PUNCT
# albowiem        COMP     SCONJ
# panowie         SUBST    NOUN
# z               PREP     ADP
# pta             SUBST    NOUN
# znali           PRAET    VERB
# ceny            SUBST    NOUN
# potraw          SUBST    NOUN
# lepiej          ADV      ADV
# niż             CONJ     SCONJ
# kelnerzy        BREV     NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Tymczasem       CONJ     ADV
# w               PREP     ADP
# bufecie         SUBST    NOUN
# panna           SUBST    NOUN
# Tola            SUBST    PROPN
# czyściła        PRAET    VERB
# koszyki         SUBST    NOUN
# do              PREP     ADP
# chleba          SUBST    NOUN
# .               INTERP   PUNCT
# Od              PREP     ADP
# czasu           SUBST    NOUN
# do              PREP     ADP
# czasu           SUBST    NOUN
# wycierała       PRAET    VERB
# palce           SUBST    NOUN
# i               CONJ     CCONJ
# sięgała         PRAET    VERB
# do              PREP     ADP
# kieszeni        SUBST    NOUN
# fartucha        SUBST    NOUN
# ,               SUBST    PUNCT
# wyjmowała       PRAET    VERB
# kruche          ADJ      ADJ
# ciastko         SUBST    NOUN
# ,               INTERP   PUNCT
# ugryzła         PRAET    VERB
# je              PPRON3   PRON
# i               CONJ     CCONJ
# znów            ADV      PART
# chowała         PRAET    VERB
# do              PREP     ADP
# kieszeni        SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Tymczasem       ADV      CCONJ
# na              PREP     ADP
# dole            SUBST    NOUN
# zaczęło         PRAET    VERB
# się             QUB      PRON
# kotłować        INF      VERB
# .               INTERP   PUNCT
# Do              PREP     ADP
# gabinetu        SUBST    NOUN
# restauracyjnego ADJ      ADJ
# wpadło          PRAET    VERB
# kilkanaście     NUM      DET
# osób            SUBST    NOUN
# -               INTERP   PUNCT
# spieszyło       PRAET    VERB
# im              PPRON3   PRON
# się             QUB      PRON
# bardzo          ADV      ADV
# ,               INTERP   PUNCT
# żądali          PRAET    VERB
# natychmiastowej ADJ      ADJ
# obsługi         SUBST    NOUN
# .               INTERP   PUNCT
# Grela           SUBST    PROPN
# zesunął         PRAET    VERB
# stoły           _SP      NOUN
# ,               INTERP   PUNCT
# Julka           SUBST    PROPN
# wysłał          PRAET    VERB
# do              PREP     ADP
# bufetu          SUBST    NOUN
# po              PREP     ADP
# jarzębiak       SUBST    NOUN
# i               CONJ     CCONJ
# masło           SUBST    NOUN
# ,               SUBST    PUNCT
# sam             ADJ      ADJ
# udał            PRAET    VERB
# się             QUB      PRON
# po              PREP     ADP
# zimne           ADJ      ADJ
# zakąski         SUBST    NOUN
# .               INTERP   PUNCT
# Okazało         PRAET    VERB
# się             QUB      PRON
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# wózek           SUBST    NOUN
# i               CONJ     CCONJ
# wszystkie       ADJ      DET
# półmiski        SUBST    NOUN
# z               PREP     ADP
# rybami          SUBST    NOUN
# zabrano         IMPS     VERB
# na              PREP     ADP
# trójkę          SUBST    NOUN
# do              PREP     ADP
# Teodora         SUBST    PROPN
# .               SUBST    PUNCT
# Teodor          SUBST    NOUN
# nie             QUB      PART
# pozwolił        PRAET    VERB
# sobie           SIEBIE   PRON
# ich             PPRON3   PRON
# odebrać         SUBST    VERB
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Boryczko        SUBST    PROPN
# rozejrzał       PRAET    VERB
# się             QUB      PRON
# szybko          ADV      ADV
# po              PREP     ADP
# rewirze         SUBST    NOUN
# -               INTERP   PUNCT
# z               PREP     ADP
# zadowoleniem    SUBST    NOUN
# stwierdził      _SP      VERB
# ,               SUBST    PUNCT
# że              COMP     SCONJ
# wśród           PREP     ADP
# kilkunastu      NUM      DET
# par             SUBST    NOUN
# oczu            SUBST    NOUN
# zwróconych      PPAS     ADJ
# w               PREP     ADP
# jego            PPRON3   PRON
# stronę          SUBST    NOUN
# nie             QUB      PART
# było            PRAET    VERB
# tych            ADJ      DET
# niebieskich     ADJ      ADJ
# -               INTERP   PUNCT
# dyskretnie      ADV      ADV
# skryły          PRAET    VERB
# się             QUB      PRON
# za              PREP     ADP
# teczką          SUBST    NOUN
# tygodnika       SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# "               INTERP   PUNCT
# Zbój            SUBST    NOUN
# Madej           SUBST    PROPN
# "               INTERP   PUNCT
# też             QUB      PART
# coś             SUBST    PRON
# wiedział        SUBST    VERB
# .               INTERP   PUNCT
# Z               PREP     ADP
# początku        SUBST    NOUN
# udawał          _SP      VERB
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# się             QUB      PRON
# tym             SUBST    PRON
# nie             QUB      PART
# interesuje      FIN      VERB
# ,               INTERP   PUNCT
# zachowywał      PRAET    VERB
# się             QUB      PRON
# wobec           PREP     ADP
# Romana          SUBST    PROPN
# tak             ADV      ADV
# jak             ADV      SCONJ
# zawsze          SUBST    ADV
# :               INTERP   PUNCT
# pociągał        PRAET    VERB
# go              PPRON3   PRON
# za              PREP     ADP
# rękaw           SUBST    NOUN
# i               CONJ     CCONJ
# powtarzał       PRAET    VERB
# zamówienia      SUBST    NOUN
# lub             CONJ     CCONJ
# prosił          SUBST    VERB
# ,               INTERP   PUNCT
# by              COMP     SCONJ
# zechciał        PRAET    VERB
# "               INTERP   PUNCT
# rzucić          INF      VERB
# okiem           SUBST    NOUN
# "               INTERP   PUNCT
# na              PREP     ADP
# jego            PPRON3   PRON
# rewir           SUBST    NOUN
# .               INTERP   PUNCT
# Ale             CONJ     CCONJ
# raz             SUBST    NOUN
# ,               INTERP   PUNCT
# gdy             ADV      ADV
# się             QUB      PRON
# zeszli          PRAET    VERB
# na              PREP     ADP
# rewirze         SUBST    NOUN
# i               CONJ     CCONJ
# nic             SUBST    PRON
# nie             QUB      PART
# mieli           PRAET    VERB
# do              PREP     ADP
# roboty          SUBST    NOUN
# ,               SUBST    PUNCT
# Robak           SUBST    PROPN
# pogłaskał       PRAET    VERB
# swoją           ADJ      DET
# łysinę          SUBST    NOUN
# i               CONJ     CCONJ
# zaczął          PRAET    VERB
# namiętnie       ADV      ADV
# gryźć           INF      VERB
# dolną           ADJ      ADJ
# wargę           SUBST    NOUN
# -               INTERP   PUNCT
# znak            SUBST    NOUN
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# ma              FIN      VERB
# coś             SUBST    PRON
# ważnego         ADJ      ADJ
# do              PREP     ADP
# powiedzenia     SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Chwila          SUBST    NOUN
# milczenia       SUBST    NOUN
# .               SUBST    PUNCT
# Romek           SUBST    PROPN
# uniósł          PRAET    VERB
# się             QUB      PRON
# na              PREP     ADP
# łokciu          SUBST    NOUN
# ,               INTERP   PUNCT
# zaczął          PRAET    VERB
# nerwowo         ADV      ADV
# mrugać          INF      VERB
# okiem           SUBST    NOUN
# ,               INTERP   PUNCT
# wreszcie        QUB      PART
# rzekł           SUBST    VERB
# :               INTERP   PUNCT
# -               INTERP   PUNCT
# Ja              PPRON12  PRON
# myślę           FIN      VERB
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# więcej          NUM      ADV
# ,               INTERP   PUNCT
# bo              COMP     SCONJ
# widzi           FIN      VERB
# pan             SUBST    NOUN
# ,               INTERP   PUNCT
# z               PREP     ADP
# tym             ADJ      DET
# okiem           SUBST    NOUN
# coś             SUBST    PRON
# nie             QUB      PART
# w               PREP     ADP
# porządku        SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Kierownik       SUBST    PROPN
# Stec            SUBST    PROPN
# wrócił          PRAET    VERB
# z               PREP     ADP
# restauracji     SUBST    NOUN
# od              PREP     ADP
# Fornalskiego    SUBST    PROPN
# ,               INTERP   PUNCT
# sprawdził       PRAET    VERB
# kasę            SUBST    NOUN
# ,               SUBST    PUNCT
# czy             QUB      PART
# jest            FIN      AUX
# skręcona        SUBST    ADJ
# ,               INTERP   PUNCT
# schował         PRAET    VERB
# kwity           SUBST    NOUN
# i               CONJ     CCONJ
# zamknął         PRAET    VERB
# szufladę        SUBST    NOUN
# .               INTERP   PUNCT
# Przez           PREP     ADP
# chwilę          SUBST    NOUN
# myślał          PRAET    VERB
# o               PREP     ADP
# czymś           SUBST    PRON
# ,               INTERP   PUNCT
# wreszcie        QUB      PART
# kiwnął          PRAET    VERB
# głową           SUBST    NOUN
# ,               INTERP   PUNCT
# powiedział      PRAET    VERB
# pannie          SUBST    NOUN
# Toli            SUBST    PROPN
# dobranoc        SUBST    NOUN
# i               CONJ     CCONJ
# uśmiechając     PCON     VERB
# się             QUB      PRON
# sam             ADJ      ADJ
# do              PREP     ADP
# siebie          SUBST    PRON
# ,               INTERP   PUNCT
# poszedł         PRAET    VERB
# do              PREP     ADP
# garderoby       SUBST    NOUN
# po              PREP     ADP
# futro           SUBST    NOUN
# .               INTERP   PUNCT
# Ubrawszy        PANT     VERB
# się             SUBST    PRON
# ,               INTERP   PUNCT
# wstąpił         PRAET    VERB
# do              PREP     ADP
# pokoju          SUBST    NOUN
# damskiego       SUBST    ADJ
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Ale             CONJ     CCONJ
# budzik          SUBST    PROPN
# jest            FIN      AUX
# dobry           SUBST    ADJ
# ,               SUBST    PUNCT
# co              QUB      PART
# ?               INTERP   PUNCT
# Ilem            SUBST    NOUN
# razy            SUBST    NOUN
# go              PPRON3   PRON
# rzucał          PRAET    VERB
# na              PREP     ADP
# podłogę         SUBST    NOUN
# i               CONJ     CCONJ
# nic             SUBST    PRON
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# ,               INTERP   PUNCT
# trzyma          FIN      VERB
# się             QUB      PRON
# kupy            SUBST    NOUN
# .               INTERP   PUNCT
# Dobra           QUB      ADJ
# marka           SUBST    NOUN
# ,               SUBST    PUNCT
# Jaz             SUBST    PROPN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# I               CONJ     CCONJ
# oto             QUB      PART
# w               PREP     ADP
# tej             ADJ      DET
# chwili          SUBST    NOUN
# pociąg          SUBST    NOUN
# z               PREP     ADP
# Helą            SUBST    PROPN
# mknął           PRAET    VERB
# przez           PREP     ADP
# zaśnieżone      PPAS     ADJ
# pola            SUBST    NOUN
# ,               SUBST    PUNCT
# a               CONJ     CCONJ
# Roman           SUBST    PROPN
# szedł           PRAET    VERB
# ostrożnie       ADV      ADV
# ulicą           SUBST    NOUN
# i               CONJ     CCONJ
# unikał          PRAET    VERB
# potrąceń        SUBST    NOUN
# ,               INTERP   PUNCT
# by              COMP     SCONJ
# nie             QUB      PART
# uronić          INF      VERB
# przedwcześnie   ADV      ADV
# ani             QUB      PART
# odrobiny        SUBST    NOUN
# płynnej         ADJ      ADJ
# żałości         SUBST    NOUN
# ,               INTERP   PUNCT
# zapełniającej   PACT     ADJ
# go              PPRON3   PRON
# aż              QUB      PART
# po              PREP     ADP
# krtań           SUBST    NOUN
# i               CONJ     CCONJ
# oczy            SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Gdzieś          ADV      ADV
# tam             ADV      ADV
# na              PREP     ADP
# "               INTERP   PUNCT
# Sybirze         SUBST    PROPN
# "               SUBST    PUNCT
# ,               INTERP   PUNCT
# niby            CONJ     SCONJ
# pająk           SUBST    NOUN
# w               PREP     ADP
# sieci           SUBST    NOUN
# ukryty          SUBST    ADJ
# ,               INTERP   PUNCT
# świdruje        FIN      VERB
# kelnerów        SUBST    NOUN
# wzrok           SUBST    NOUN
# starego         ADJ      ADJ
# Pancera         SUBST    PROPN
# -               INTERP   PUNCT
# czują           FIN      VERB
# go              PPRON3   PRON
# nawet           QUB      PART
# ci              ADJ      DET
# ,               INTERP   PUNCT
# w               PREP     ADP
# drugim          ADJ      ADJ
# końcu           SUBST    NOUN
# kawiarni        SUBST    NOUN
# ,               INTERP   PUNCT
# za              PREP     ADP
# czwartą         ADJ      ADJ
# ścianą          SUBST    NOUN
# z               PREP     ADP
# cegły           SUBST    NOUN
# .               INTERP   PUNCT
# Niechby         QUB      AUX
# się             QUB      PRON
# już             QUB      PART
# wyniósł         PRAET    VERB
# stąd            ADV      ADV
# ,               INTERP   PUNCT
# a               CONJ     CCONJ
# zrobiłoby       SUBST    VERB
# się             QUB      PRON
# dobrze          ADV      ADV
# jak             ADV      SCONJ
# po              PREP     ADP
# wyrwaniu        GER      NOUN
# chorego         SUBST    ADJ
# zęba            SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Nie             SUBST    PART
# ,               INTERP   PUNCT
# "               INTERP   PUNCT
# Kucyk           SUBST    NOUN
# "               SUBST    PUNCT
# nie             QUB      PART
# miał            PRAET    VERB
# powodzenia      SUBST    NOUN
# wśród           PREP     ADP
# personelu       SUBST    NOUN
# ,               SUBST    PUNCT
# a               CONJ     CCONJ
# najmniej        ADV      ADV
# u               PREP     ADP
# kelnerów        SUBST    NOUN
# .               SUBST    PUNCT
# Jego            PPRON3   PRON
# motorkowo       SUBST    ADJ
# -               ADJ      PUNCT
# pęcherzykowa    ADJ      ADJ
# ruchliwość      SUBST    NOUN
# i               CONJ     CCONJ
# "               INTERP   PUNCT
# cudeńka         SUBST    NOUN
# "               SUBST    PUNCT
# ,               INTERP   PUNCT
# jakie           ADJ      DET
# pokazywał       PRAET    VERB
# przed           PREP     ADP
# gośćmi          SUBST    NOUN
# ,               INTERP   PUNCT
# budziły         PRAET    VERB
# raczej          QUB      PART
# wesołość        SUBST    NOUN
# niż             CONJ     SCONJ
# podziw          ADJ      NOUN
# .               SUBST    PUNCT
# Zrażony         PPAS     ADJ
# do              PREP     ADP
# kelnerów        SUBST    NOUN
# ,               INTERP   PUNCT
# zapędzał        PRAET    VERB
# się             QUB      PRON
# do              PREP     ADP
# kuchni          SUBST    NOUN
# ,               INTERP   PUNCT
# ale             CONJ     CCONJ
# tam             ADV      ADV
# znów            QUB      PART
# gruby           _SP      ADJ
# ,               INTERP   PUNCT
# wąsaty          ADJ      ADJ
# szef            SUBST    NOUN
# Balcer          SUBST    PROPN
# pokazywał       PRAET    VERB
# mu              PPRON3   PRON
# kły             SUBST    NOUN
# :               INTERP   PUNCT
# -               INTERP   PUNCT
# Co              SUBST    PRON
# pan             SUBST    NOUN
# tu              ADV      ADV
# chce            FIN      VERB
# ,               INTERP   PUNCT
# do              PREP     ADP
# rondli          SUBST    VERB
# zaglądać        INF      VERB
# i               CONJ     CCONJ
# uczyć           INF      VERB
# ,               INTERP   PUNCT
# jak             ADV      ADV
# sosy            SUBST    NOUN
# przyprawiać     SUBST    VERB
# !               SUBST    PUNCT
# ?               INTERP   PUNCT
#
#                _SP      SPACE
# Stary           ADJ      ADJ
# Pancer          SUBST    NOUN
# ,               SUBST    PUNCT
# z               PREP     ADP
# rękami          SUBST    NOUN
# w               PREP     ADP
# kieszeniach     SUBST    NOUN
# spodni          SUBST    NOUN
# ,               INTERP   PUNCT
# stał            PRAET    VERB
# oparty          PPAS     ADJ
# o               PREP     ADP
# biurko          SUBST    NOUN
# .               ADJ      PUNCT
# Krótkie         ADJ      ADJ
# nogi            SUBST    NOUN
# założone        PPAS     ADJ
# jedna           ADJ      ADJ
# na              PREP     ADP
# drugą           ADJ      ADJ
# ,               INTERP   PUNCT
# dolna           ADJ      ADJ
# warga           SUBST    NOUN
# wysunięta       ADJ      ADJ
# ,               INTERP   PUNCT
# oczka           SUBST    NOUN
# zmrużone        PPAS     ADJ
# i               CONJ     CCONJ
# patrzące        PACT     ADJ
# tak             ADV      ADV
# samo            ADV      ADV
# jak             ADV      SCONJ
# o               PREP     ADP
# godzinie        SUBST    NOUN
# dwunastej       ADJ      ADJ
# spośród         PREP     ADP
# kolorowych      ADJ      ADJ
# wstęg           SUBST    NOUN
# i               CONJ     CCONJ
# baloników       SUBST    NOUN
# koło            PREP     ADP
# drzwi           SUBST    NOUN
# kuchennych      NUM      ADJ
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Gdzieś          ADV      ADV
# tam             ADV      ADV
# w               PREP     ADP
# kłębach         SUBST    NOUN
# pary            SUBST    NOUN
# dojrzał         PRAET    VERB
# i               CONJ     CCONJ
# zapamiętał      PRAET    VERB
# dziewczęcą      ADJ      ADJ
# twarz           SUBST    NOUN
# pomocnicy       SUBST    NOUN
# kawiarki        SUBST    NOUN
# ,               INTERP   PUNCT
# i               CONJ     CCONJ
# znów            ADV      PART
# oczy            SUBST    NOUN
# ,               INTERP   PUNCT
# tym             ADJ      DET
# razem           SUBST    NOUN
# bure            SUBST    NOUN
# ,               INTERP   PUNCT
# figlarne        ADJ      ADJ
# i               CONJ     CCONJ
# wyłupiaste      ADJ      ADJ
# jak             ADV      SCONJ
# u               PREP     ADP
# wiewiórki       SUBST    NOUN
# .               SUBST    PUNCT
# Czując          SUBST    VERB
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# mu              PPRON3   PRON
# gorąca          ADJ      ADJ
# fala            SUBST    NOUN
# zalewa          FIN      VERB
# policzki        SUBST    NOUN
# ,               INTERP   PUNCT
# niezgrabnie     ADV      ADV
# postawił        PRAET    VERB
# szklankę        SUBST    NOUN
# na              PREP     ADP
# półce           SUBST    NOUN
# i               CONJ     CCONJ
# nie             QUB      PART
# widząc          PCON     VERB
# nic             SUBST    PRON
# wycofał         PRAET    VERB
# się             QUB      PRON
# na              PREP     ADP
# dużą            ADJ      ADJ
# salę            SUBST    NOUN
# .               SUBST    PUNCT
# Szedł           PRAET    VERB
# na              PREP     ADP
# oślep           BURK     X
# w               PREP     ADP
# kierunku        SUBST    NOUN
# swojego         ADJ      DET
# rewiru          SUBST    NOUN
# ,               INTERP   PUNCT
# szedł           PRAET    VERB
# coraz           ADV      ADV
# wolniej         ADV      ADV
# ,               INTERP   PUNCT
# wreszcie        QUB      PART
# potknął         PRAET    VERB
# się             QUB      PRON
# o               PREP     ADP
# krzesło         SUBST    NOUN
# i               CONJ     CCONJ
# stanął          PRAET    VERB
# w               PREP     ADP
# miejscu         SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Na              PREP     ADP
# korytarzu       SUBST    NOUN
# ozwały          PRAET    VERB
# się             QUB      PRON
# czyjeś          ADJ      DET
# kroki           SUBST    NOUN
# -               INTERP   PUNCT
# Henek           SUBST    PROPN
# podniósł        PRAET    VERB
# wskazujący      ADJ      ADJ
# palec           SUBST    NOUN
# do              PREP     ADP
# góry            SUBST    NOUN
# :               SUBST    PUNCT
# -               INTERP   PUNCT
# Ty              SUBST    PRON
# ,               INTERP   PUNCT
# ja              PPRON12  PRON
# cię             PPRON12  PRON
# proszę          FIN      VERB
# ,               INTERP   PUNCT
# Adamowi         SUBST    PROPN
# nie             QUB      PART
# mów             IMPT     VERB
# nic             SUBST    PRON
# ,               INTERP   PUNCT
# ona             PPRON3   PRON
# prosiła         SUBST    VERB
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               INTERP   PUNCT
# i               CONJ     CCONJ
# w               PREP     ADP
# ogóle           SUBST    NOUN
# nikomu          SUBST    PRON
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               SUBST    PUNCT
#
#                _SP      SPACE
# I               CONJ     CCONJ
# znowu           ADV      PART
# nic             SUBST    PRON
# .               SUBST    PUNCT
# Czarne          ADJ      ADJ
# ,               INTERP   PUNCT
# migotliwe       ADJ      ADJ
# oczy            SUBST    NOUN
# wpatrzyły       PRAET    VERB
# się             QUB      PRON
# w               PREP     ADP
# Boryczkę        SUBST    PROPN
# ,               SUBST    PUNCT
# pyzata          ADJ      ADJ
# twarz           SUBST    NOUN
# i               CONJ     CCONJ
# zadarty         ADJ      ADJ
# nos             SUBST    NOUN
# jakby           QUB      PART
# napęczniały     PRAET    VERB
# od              PREP     ADP
# krwi            SUBST    NOUN
# .               SUBST    PUNCT
# "               INTERP   PUNCT
# Smieszny        ADJ      ADJ
# jest            FIN      AUX
# ten             ADJ      DET
# baron           SUBST    NOUN
# i               CONJ     CCONJ
# podobny         ADJ      ADJ
# do              PREP     ADP
# kogoś           SUBST    PRON
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               INTERP   PUNCT
# aha             INTERJ   PROPN
# ,               INTERP   PUNCT
# do              PREP     ADP
# parobka         SUBST    NOUN
# Wicka           SUBST    PROPN
# .               SUBST    PUNCT
# A               CONJ     PART
# może            QUB      PART
# to              PRED     AUX
# naprawdę        QUB      PART
# Wicek           SUBST    PROPN
# ,               INTERP   PUNCT
# tylko           CONJ     CCONJ
# przebrany       PPAS     ADJ
# i               CONJ     CCONJ
# bogaty          ADJ      ADJ
# ?               INTERP   PUNCT
# E               BREV     X
# ,               INTERP   PUNCT
# nie             SUBST    PART
# ,               INTERP   PUNCT
# Wicek           SUBST    PROPN
# młodszy         ADJ      ADJ
# od              PREP     ADP
# niego           BREV     PRON
# .               SUBST    PUNCT
# "               INTERP   PUNCT
# -               INTERP   PUNCT
# Panie           SUBST    NOUN
# baronie         SUBST    NOUN
# ,               SUBST    PUNCT
# "               INTERP   PUNCT
# London          SUBST    PROPN
# News            SUBST    PROPN
# "               INTERP   PUNCT
# jest            FIN      AUX
# świeży          ADJ      ADJ
# -               INTERP   PUNCT
# otwarł          PRAET    VERB
# tytułową        ADJ      ADJ
# stronicą        SUBST    NOUN
# tygodnika       SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# O               PREP     ADP
# godzinie        SUBST    NOUN
# ósmej           ADJ      ADJ
# wszyscy         ADJ      DET
# kelnerzy        SUBST    NOUN
# i               CONJ     CCONJ
# pikole          SUBST    NOUN
# byli            PRAET    VERB
# już             QUB      PART
# na              PREP     ADP
# korytarzu       SUBST    NOUN
# kuchennym       ADJ      ADJ
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               INTERP   PUNCT
# Palmiak         SUBST    PROPN
# podchmielony    ADJ      ADJ
# i               CONJ     CCONJ
# wesoły          ADJ      ADJ
# wychylił        PRAET    VERB
# głowę           SUBST    NOUN
# przez           PREP     ADP
# okno            SUBST    NOUN
# :               SUBST    PUNCT
# -               INTERP   PUNCT
# Panowie         SUBST    NOUN
# !               SUBST    PUNCT
# !               SUBST    PUNCT
# !               INTERP   PUNCT
# -               INTERP   PUNCT
# wrzasnął        PRAET    VERB
# -               INTERP   PUNCT
# bufet           SUBST    NOUN
# wydawać         SUBST    VERB
# !               SUBST    PUNCT
#
#                _SP      SPACE
# Henek           SUBST    NOUN
# opiekuńczo      ADV      ADV
# krążył          PRAET    VERB
# w               PREP     ADP
# pobliżu         SUBST    NOUN
# .               SUBST    PUNCT
# -               INTERP   PUNCT
# Umiesz          FIN      VERB
# markować        INF      VERB
# na              PREP     ADP
# kasie           SUBST    NOUN
# ?               SUBST    PUNCT
#
#                _SP      SPACE
# Henek           SUBST    PROPN
# rozejrzał       PRAET    VERB
# się             QUB      PRON
# wokoło          ADV      ADV
# i               CONJ     CCONJ
# pewny           SUBST    ADJ
# ,               SUBST    PUNCT
# że              COMP     SCONJ
# nikt            SUBST    PRON
# nie             QUB      PART
# patrzy          FIN      VERB
# ,               INTERP   PUNCT
# zaczął          PRAET    VERB
# tupać           INF      VERB
# o               PREP     ADP
# podłogę         SUBST    NOUN
# i               CONJ     CCONJ
# krzyczeć        INF      VERB
# chrapliwym      ADJ      ADJ
# głosem          SUBST    NOUN
# :               SUBST    PUNCT
# -               INTERP   PUNCT
# Psiakrew        BREV     NOUN
# !               SUBST    PUNCT
# Smarkacz        SUBST    NOUN
# !               SUBST    PUNCT
# Bijesz          SUBST    VERB
# !               INTERP   PUNCT
# Na              PREP     ADP
# kasie           SUBST    NOUN
# !               INTERP   PUNCT
# Nie             QUB      PART
# pamiętasz       _SP      VERB
# !               INTERP   PUNCT
# Co              SUBST    PRON
# robisz          FIN      VERB
# !               SUBST    PUNCT
# Psiakrew        SUBST    NOUN
# !               INTERP   PUNCT
# Smarkacz        SUBST    NOUN
# !               SUBST    PUNCT
#
#                _SP      SPACE
# Wszystko        SUBST    PRON
# wydało          PRAET    VERB
# mu              PPRON3   PRON
# się             QUB      PRON
# pozbawione      PPAS     ADJ
# tajemniczości   SUBST    NOUN
# ,               INTERP   PUNCT
# ograniczone     ADJ      ADJ
# czasem          SUBST    NOUN
# i               CONJ     CCONJ
# przestrzenią    SUBST    NOUN
# ,               SUBST    PUNCT
# objęte          PPAS     ADJ
# umysłem         SUBST    NOUN
# i               CONJ     CCONJ
# nieskomplikowane SUBST    ADJ
# .               INTERP   PUNCT
# Szedłby         SUBST    VERB
# o               PREP     ADP
# zakład          SUBST    NOUN
# ,               SUBST    PUNCT
# że              COMP     SCONJ
# da              FIN      VERB
# radę            SUBST    NOUN
# obsłużyć        INF      VERB
# wszystkie       ADJ      DET
# rewiry          SUBST    NOUN
# w               PREP     ADP
# kawiarni        SUBST    NOUN
# i               CONJ     CCONJ
# ...
# uspokojenie     SUBST    NOUN
# "               SUBST    PUNCT
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Roman           SUBST    PROPN
# klęczał         PRAET    VERB
# na              PREP     ADP
# posadzce        SUBST    NOUN
# i               CONJ     CCONJ
# szukał          PRAET    VERB
# pieniędzy       SUBST    NOUN
# ,               INTERP   PUNCT
# które           ADJ      DET
# mu              PPRON3   PRON
# podczas         PREP     ADP
# inkasowania     GER      NOUN
# wypadły         PRAET    VERB
# z               PREP     ADP
# ręki            SUBST    NOUN
# .               INTERP   PUNCT
# Chodził         PRAET    VERB
# tak             ADV      ADV
# na              PREP     ADP
# raczkach        SUBST    NOUN
# po              PREP     ADP
# całym           ADJ      ADJ
# rewirze         SUBST    NOUN
# ,               SUBST    PUNCT
# zaglądał        PRAET    VERB
# pod             PREP     ADP
# foteliki        SUBST    NOUN
# i               CONJ     CCONJ
# kanapy          SUBST    NOUN
# ,               SUBST    PUNCT
# ściereczka      SUBST    NOUN
# zwisała         PRAET    VERB
# mu              PPRON3   PRON
# z               PREP     ADP
# kieszeni        SUBST    NOUN
# ,               INTERP   PUNCT
# włosy           SUBST    NOUN
# opadły          PRAET    VERB
# na              PREP     ADP
# czoło           SUBST    NOUN
# -               INTERP   PUNCT
# musiał          PRAET    VERB
# je              PPRON3   PRON
# co              PREP     ADP
# chwila          SUBST    NOUN
# zarzucać        INF      VERB
# w               PREP     ADP
# tył             SUBST    NOUN
# .               SUBST    PUNCT
#
#                _SP      SPACE
# On              PPRON3   PRON
# jest            FIN      AUX
# teraz           ADV      ADV
# na              PREP     ADP
# mnie            PPRON12  PRON
# zły             SUBST    ADJ
# ,               INTERP   PUNCT
# bo              COMP     SCONJ
# myśli           SUBST    VERB
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# ja              PPRON12  PRON
# mu              PPRON3   PRON
# to              SUBST    PART
# naumyślnie      ADV      ADV
# zrobiłem        ADJ      VERB
# .               INTERP   PUNCT
# Jakże           QUB      ADV
# bym             QUB      AUX
# ja              PPRON12  PRON
# śmiał           SUBST    VERB
# .               SUBST    PUNCT
# .               SUBST    PUNCT
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Około           PREP     ADP
# jedenastej      ADJ      ADJ
# śniadania       SUBST    NOUN
# się             QUB      PRON
# kończyły        SUBST    VERB
# ,               INTERP   PUNCT
# zamawiano       IMPS     VERB
# czarne          ADJ      ADJ
# kawy            SUBST    NOUN
# ,               INTERP   PUNCT
# herbaty         SUBST    NOUN
# i               CONJ     CCONJ
# kapucyny        SUBST    NOUN
# .               SUBST    PUNCT
# "               INTERP   PUNCT
# Sybir           SUBST    NOUN
# "               INTERP   PUNCT
# ział            PRAET    VERB
# pustką          SUBST    NOUN
# -               INTERP   PUNCT
# Wieliński       SUBST    PROPN
# i               CONJ     CCONJ
# Bandera         SUBST    PROPN
# patrzyli        PRAET    VERB
# przez           PREP     ADP
# okno            SUBST    NOUN
# na              PREP     ADP
# ulicę           SUBST    NOUN
# i               CONJ     CCONJ
# wzrokiem        SUBST    NOUN
# odprowadzali    PRAET    VERB
# przechodniów    SUBST    NOUN
# lub             CONJ     CCONJ
# gapili          PRAET    VERB
# się             QUB      PRON
# na              PREP     ADP
# gzymsy          SUBST    NOUN
# przyprószone    PPAS     ADJ
# śniegiem        SUBST    NOUN
# i               CONJ     CCONJ
# ołowiany        ADJ      ADJ
# skrawek         SUBST    NOUN
# nieba           SUBST    NOUN
# ,               INTERP   PUNCT
# zabudowany      PPAS     ADJ
# kominami        SUBST    NOUN
# przyległych     ADJ      ADJ
# kamienic        SUBST    NOUN
# i               CONJ     CCONJ
# zasiekami       SUBST    NOUN
# anten           SUBST    NOUN
# radiowych       ADJ      ADJ
# ,               INTERP   PUNCT
# sterczących     PACT     ADJ
# wichrowato      ADV      ADV
# jak             PREP     SCONJ
# drewniane       ADJ      ADJ
# krzyże          SUBST    NOUN
# na              PREP     ADP
# starym          ADJ      ADJ
# cmentarzu       SUBST    NOUN
# .               INTERP   PUNCT
#
#                _SP      SPACE
# Roman           SUBST    PROPN
# dźwignął        PRAET    VERB
# nowy            ADJ      ADJ
# ładunek         SUBST    NOUN
# podwieczorków   SUBST    NOUN
# i               CONJ     CCONJ
# ruszył          PRAET    VERB
# na              PREP     ADP
# salę            SUBST    NOUN
# .               INTERP   PUNCT
# Tuż             QUB      PART
# przed           PREP     ADP
# nim             PPRON3   PRON
# szedł           PRAET    VERB
# Kantara         SUBST    PROPN
# -               INTERP   PUNCT
# trzymał         PRAET    VERB
# w               PREP     ADP
# rękach          SUBST    NOUN
# tak             ADV      PART
# dużo            NUM      DET
# tacek           SUBST    NOUN
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# aby             COMP     SCONJ
# zrównoważyć     INF      VERB
# ich             PPRON3   PRON
# ciężar          SUBST    NOUN
# ,               INTERP   PUNCT
# przechylił      PRAET    VERB
# się             QUB      PRON
# w               PREP     ADP
# tył             SUBST    NOUN
# i               CONJ     CCONJ
# łokieć          SUBST    NOUN
# oparł           PRAET    VERB
# na              PREP     ADP
# brzuchu         SUBST    NOUN
# .               INTERP   PUNCT
# Chcąc           PCON     VERB
# go              PPRON3   PRON
# pośpieszyć      INF      VERB
# Roman           SUBST    PROPN
# krzyknął        PRAET    VERB
# mu              PPRON3   PRON
# nad             PREP     ADP
# uchem           SUBST    NOUN
# :               SUBST    PUNCT
# "               INTERP   PUNCT
# prędzej         SUBST    ADV
# !               SUBST    PUNCT
# "               INTERP   PUNCT
# -               INTERP   PUNCT
# Kantara         SUBST    PROPN
# obejrzał        PRAET    VERB
# się             QUB      PRON
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Nikt            SUBST    PRON
# się             QUB      PRON
# na              PREP     ADP
# to              SUBST    PRON
# nie             QUB      PART
# odezwał         PRAET    VERB
# -               INTERP   PUNCT
# Bandera         SUBST    PROPN
# zna             FIN      VERB
# się             QUB      PRON
# na              PREP     ADP
# tym             SUBST    PRON
# lepiej          ADV      ADV
# od              PREP     ADP
# innych          SUBST    NOUN
# .               INTERP   PUNCT
# Kiedyś          ADV      ADV
# powiedział      PRAET    VERB
# tak             ADV      ADV
# :               INTERP   PUNCT
# "               INTERP   PUNCT
# I               CONJ     CCONJ
# cóż             SUBST    PRON
# z               PREP     ADP
# tego            SUBST    PRON
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# ci              ADJ      DET
# wszyscy         ADJ      DET
# filozofowie     SUBST    NOUN
# grzebią         FIN      VERB
# w               PREP     ADP
# książkach       SUBST    NOUN
# i               CONJ     CCONJ
# tak             ADV      ADV
# dużo            NUM      ADV
# myślą           SUBST    VERB
# ?               INTERP   PUNCT
# Co              SUBST    PRON
# dokonali        SUBST    VERB
# ?               SUBST    PUNCT
# Nic             SUBST    PRON
# .               SUBST    PUNCT
# A               CONJ     CCONJ
# najzabawniejsze ADJ      ADJ
# to              SUBST    PRON
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# zawsze          ADV      ADV
# wracają         FIN      VERB
# tam             ADV      ADV
# ,               INTERP   PUNCT
# skąd            ADV      ADV
# wyszli          SUBST    VERB
# "               SUBST    PUNCT
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Wieczorami      SUBST    NOUN
# spacerował      PRAET    VERB
# wzdłuż          PREP     ADP
# kawiarni        SUBST    NOUN
# i               CONJ     CCONJ
# zaglądał        PRAET    VERB
# w               PREP     ADP
# okna            SUBST    NOUN
# pod             PREP     ADP
# firanki         SUBST    NOUN
# .               INTERP   PUNCT
# Do              PREP     ADP
# interesu        SUBST    NOUN
# przychodził     PRAET    VERB
# o               PREP     ADP
# szóstej         ADJ      ADJ
# rano            SUBST    ADV
# ,               INTERP   PUNCT
# stawał          PRAET    VERB
# w               PREP     ADP
# garderobie      SUBST    NOUN
# kawiarnianej    SUBST    ADJ
# ,               INTERP   PUNCT
# wyjmował        PRAET    VERB
# zegarek         SUBST    NOUN
# i               CONJ     CCONJ
# notes           SUBST    NOUN
# i               CONJ     CCONJ
# zapisywał       PRAET    VERB
# tych            ADJ      DET
# ,               INTERP   PUNCT
# którzy          ADJ      DET
# się             QUB      PRON
# spóźniali       PRAET    VERB
# -               INTERP   PUNCT
# już             QUB      PART
# pierwszego      ADJ      ADJ
# dnia            SUBST    NOUN
# trafikantce     SUBST    NOUN
# i               CONJ     CCONJ
# paru            NUM      DET
# kelnerom        SUBST    NOUN
# nałożył         PRAET    VERB
# grzywny         SUBST    NOUN
# po              PREP     ADP
# pięć            NUM      NUM
# złotych         SUBST    NOUN
# na              PREP     ADP
# cele            SUBST    NOUN
# dobroczynne     SUBST    ADJ
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Mimo            PREP     ADP
# to              SUBST    PRON
# Roman           SUBST    PROPN
# zbliżył         PRAET    VERB
# się             QUB      PRON
# do              PREP     ADP
# stołu           SUBST    NOUN
# ,               INTERP   PUNCT
# oparł           PRAET    VERB
# się             QUB      PRON
# o               PREP     ADP
# czyjeś          ADJ      DET
# krzesło         SUBST    NOUN
# i               CONJ     CCONJ
# płaczliwym      ADJ      ADJ
# głosem          SUBST    NOUN
# zapytał         SUBST    VERB
# :               INTERP   PUNCT
# -               INTERP   PUNCT
# Jaśnie          ADV      ADV
# pan             SUBST    NOUN
# redaktor        SUBST    NOUN
# życzył          PRAET    VERB
# sobie           SIEBIE   PRON
# "               INTERP   PUNCT
# Kuriera         SUBST    PROPN
# "               SUBST    PUNCT
# ?               INTERP   PUNCT
# Niech           QUB      AUX
# mi              PPRON12  PRON
# jaśnie          ADV      ADV
# pan             SUBST    NOUN
# wierzy          SUBST    VERB
# ,               SUBST    PUNCT
# że              COMP     SCONJ
# nie             QUB      PART
# ma              FIN      VERB
# ani             QUB      PART
# jednego         ADJ      ADJ
# ,               INTERP   PUNCT
# wszystkie       ADJ      DET
# są              FIN      AUX
# zajęte          SUBST    ADJ
# ,               INTERP   PUNCT
# jak             ADV      SCONJ
# Boga            SUBST    PROPN
# kocham          FIN      VERB
# ,               SUBST    PUNCT
# że              COMP     SCONJ
# zajęte          SUBST    ADJ
# .               SUBST    PUNCT
#
#                _SP      SPACE
# Istotnie        SUBST    PART
# ,               INTERP   PUNCT
# w               PREP     ADP
# damskim         ADJ      ADJ
# pokoju          SUBST    NOUN
# aż              QUB      PART
# syczało         SUBST    VERB
# .               INTERP   PUNCT
# Roman           SUBST    PROPN
# wpadł           PRAET    VERB
# na              PREP     ADP
# swój            ADJ      DET
# rewir           SUBST    NOUN
# jak             ADV      SCONJ
# w               PREP     ADP
# nagalwanizowane PPAS     ADJ
# pole            SUBST    NOUN
# .               INTERP   PUNCT
# Ze              PREP     ADP
# wszech          ADJ      DET
# stron           SUBST    NOUN
# wołano          IMPS     VERB
# płacić          SUBST    VERB
# ,               INTERP   PUNCT
# trzymane        PPAS     ADJ
# w               PREP     ADP
# palcach         SUBST    NOUN
# banknoty        SUBST    NOUN
# powiewały       PRAET    VERB
# w               PREP     ADP
# powietrzu       SUBST    NOUN
# ,               SUBST    PUNCT
# monety          SUBST    NOUN
# rzucane         PPAS     ADJ
# na              PREP     ADP
# marmur          SUBST    NOUN
# wpadały         PRAET    VERB
# w               PREP     ADP
# kołujący        SUBST    ADJ
# ,               INTERP   PUNCT
# jednostajnie    ADV      ADV
# przyspieszony   PPAS     ADJ
# ruch            SUBST    NOUN
# lub             CONJ     CCONJ
# toczyły         PRAET    VERB
# się             QUB      PRON
# na              PREP     ADP
# brzeg           SUBST    NOUN
# stołu           SUBST    NOUN
# i               CONJ     CCONJ
# tam             SUBST    ADV
# ,               INTERP   PUNCT
# przytrzymane    PPAS     ADJ
# gwałtownym      ADJ      ADJ
# skokiem         SUBST    NOUN
# ręki            SUBST    NOUN
# ,               SUBST    PUNCT
# wydawały        PRAET    VERB
# krótki          ADJ      ADJ
# fałszywy        ADJ      NOUN
# dźwięk          SUBST    NOUN
# .               INTERP   PUNCT
#
#                _SP      SPACE
# "               INTERP   PUNCT
# Zostawiłam      FIN      VERB
# płaszcz         SUBST    NOUN
# przy            PREP     ADP
# piecu           SUBST    NOUN
# ,               SUBST    PUNCT
# żeby            COMP     SCONJ
# wysechł         SUBST    VERB
# ,               SUBST    PUNCT
# i               CONJ     CCONJ
# cały            ADJ      ADJ
# przód           SUBST    NOUN
# się             QUB      PRON
# przyżelił       FIN      VERB
# .               INTERP   PUNCT
# Nie             QUB      PART
# gniewaj         IMPT     VERB
# się             QUB      PRON
# ,               INTERP   PUNCT
# bardzo          ADV      ADV
# cię             PPRON12  PRON
# proszę          FIN      VERB
# ,               INTERP   PUNCT
# przyślij        IMPT     VERB
# mi              PPRON12  PRON
# dwadzieścia     NUM      NUM
# złotych         SUBST    NOUN
# ,               INTERP   PUNCT
# ja              PPRON12  PRON
# ci              PPRON12  PRON
# je              PPRON3   PRON
# oddam           FIN      VERB
# po              PREP     ADP
# pierwszym       SUBST    ADJ
# "               SUBST    PUNCT
# .               INTERP   PUNCT
# Posłał          PRAET    VERB
# jej             PPRON3   PRON
# dwadzieścia     NUM      NUM
# złotych         SUBST    NOUN
# ,               INTERP   PUNCT
# ale             CONJ     CCONJ
# to              SUBST    PART
# go              PPRON3   PRON
# tak             ADV      ADV
# rozgoryczyło    ADV      VERB
# ,               INTERP   PUNCT
# że              COMP     SCONJ
# w               PREP     ADP
# tym             ADJ      DET
# samym           ADJ      ADJ
# dniu            SUBST    NOUN
# zapłacił        PRAET    VERB
# czynsz          SUBST    NOUN
# ,               INTERP   PUNCT
# podatek         SUBST    NOUN
# i               CONJ     CCONJ
# składki         SUBST    NOUN
# miesięczne      ADJ      ADJ
# do              PREP     ADP
# Związku         SUBST    NOUN
# ,               INTERP   PUNCT
# praczce         SUBST    PROPN
# dał             PRAET    VERB
# zaległe         ADJ      ADJ
# piętnaście      NUM      ADP
# złotych         SUBST    NOUN
# i               CONJ     CCONJ
# krawcowi        SUBST    NOUN
# spłacił         PRAET    VERB
# dwie            NUM      NUM
# ostatnie        ADJ      ADJ
# raty            SUBST    NOUN
# za              PREP     ADP
# ubranie         SUBST    NOUN
# .               SUBST    PUNCT

# %%
# !pip install morfeusz2
# Out:
# ERROR: Could not find a version that satisfies the requirement morfeusz2 (from versions: none)
# ERROR: No matching distribution found for morfeusz2

# %% [markdown]
# # Zadanie 4
#
# Charakterystyka stylów literackich wiąże się z proprocjami części mowy w tekście, co widac na wykresie :
#
#  ![Procentowe.png](data:image/png;base64,...)
#
#  Dla tekstu z zadania 3 oraz dla tekstu z pliku 2.txt wykonaj :
#
# *   Policz procentową zawartość części mowy w tekście
# *   Z procentowego rozkładu części mowy  i załączonego wykresuspróbuj określic z jakim typem tekstu masz od czynienia
# *   Spróbuj poprawić wyniki używają stop words ( w spaCy, poszukaj metody w dokumentacji, pamiętaj że potrzebujesz narzędzi do języka polskiego)

# %%
# kod zadania 4
with open("1.txt", "r") as f:
    text = f.read()

doc1 = nlp(text)

with open("2.txt", "r", encoding="windows-1250") as f:
    text = f.read()

doc2 = nlp(text)

# %%
doc1
# Out:
# Natychmiast ujrzał jej zdumione oczy, potem siebie samego w postawie klęczącej i - tak jak niegdyś, podczas deszczowej nocy na balkonie - niby ślimak dotknięty w różki, skurczył się i cofnął w głąb siebie samego.
# Baron schylił głowę, jak gdyby się przyglądał swoim butom myślał o czymś. Gdzieś tam w toalecie cicho zaskrzypiały drzwi, a na dużej sali czyjeś kroki szybko zdążały w tę stronę. Baron ocknął się z zamyślenia - jego czarne, niespokojne oczy na krótko spoczęły na twarzy Romana.
# Pikole, przebrani w czyste kaftany i fartuchy, zeszli już na dół. Ten i ów zajrzał na korytarz, uchylił drzwi do kawiarni i cofnął się, jak gdyby ujrzał tam coś niemiłego. Adaś zdołał ukraść pannom bufetowym kilkanaście talerzyków i zanieść je na swój kredensowy stolik. Bardzo go to cieszyło.
# Z pokoju wyszła Paulina. Poprawiając sobie włosy rozejrzała się po korytarzu i majestatycznym krokiem oddaliła się do swojego mieszkania .
# W chwili gdy Palmiak zapiał po raz pierwszy, Grela flirtował z dziewczętami w umywalni. Pragnąc się popisać odwagą, podszedł go ryczącego Palmiaka z zamiarem uspokojenia go, ale w tej samej chwili odskoczył od niego i runął na kredens.
# Odwróciwszy się omal nie uderzył w brzuch starego Pancera. - O, przepraszam! - zawołał patrząc w jego przymrużone oczka. - Bartek! Przynieś tu panu słomkę do lemoniady, bo zapomniałem - czuł, że szczere przyznanie się do winy zjedna mu starego i odwrócił jego uwagę od gorszych rzeczy - tam przecież jeszcze cztery stoły... Stary oparł się o ścianę, jak gdyby zamierzał długo pozostać na tym rewirze.
# Ktoś z tamtej strony przytrzymywał drzwi, bufetowiec Bujas mocował się z nimi, próbował to jednego, to drugiego skrzydła, wreszcie dostrzegłszy, że to pikolo Henek tak mocno je trzyma, pchnął z całej siły i wpadł na korytarz.
# "Dosyć! Ani słowa więcej". - Złamał kartkę na pół i wraz z banknotem wsunął ją do koperty, zakleił i zaadresował: "Wny Pan Baron Humaniewski. Hotel Pacyfik w/m". Po czym bojaźliwie otwarł drzwi hotelowe. Hall o tej godzinie był pusty - jedynie portier, gruby, majestatyczny pan w brązowym uniformie ze złoconymi naszywkami, siedział w swej loży i pił czarną kawę, którą mu Roman przed kwadransem przyniósł.
# Drugiego dnia, gdy się trochę oswoił z umywalnią, zaczął zwracać uwagę na półmiski znoszone przez pikolaków. Już wczoraj zauważył, że parobcy porywali łapczywie kawałki mięsa, więc miał wielką ochotę to samo robić: - No weź sobie - zachęciła go jedna z dziewcząt widząc jego odruch.
# Tak trwało do godziny dwunastej, to jest do trzech ważnych i szybko po sobie następujących wydarzeń.
# Podskórny uśmiech twarzy Fornalskiego wyciekł na wierzch. - No proszę - rzekł do starego rozkładając ręce i wtulając głowę między barki, jakby zgorszony beznadziejną głupotą Boryczki - wyraźnie słyszał, jak gość zamawiał Martella z trzema gwiazdkami...
# Co pewien czas panny wymyślały takie wieloznaczne słowa i ruchy wzbudzające śmiech i mające na celu skrócenie skomplikowanych określeń: "jesteś pan ciężkomyślący" - w odniesieniu do Janika, lub: "jesteś pan nieprzytomny" - w odniesieniu do Kantary. Niedawno temu posługiwały się słówkami "był" i "biedny" - pierwsze wymawiano krótko, drugie z politowaniem i kiwaniem głowy.
# Zdawał sobie jednak sprawę, że będzie mu trudno to zrobić, albowiem panowie z pta znali ceny potraw lepiej niż kelnerzy.
# Tymczasem w bufecie panna Tola czyściła koszyki do chleba. Od czasu do czasu wycierała palce i sięgała do kieszeni fartucha, wyjmowała kruche ciastko, ugryzła je i znów chowała do kieszeni.
# Tymczasem na dole zaczęło się kotłować. Do gabinetu restauracyjnego wpadło kilkanaście osób - spieszyło im się bardzo, żądali natychmiastowej obsługi. Grela zesunął stoły, Julka wysłał do bufetu po jarzębiak i masło, sam udał się po zimne zakąski. Okazało się, że wózek i wszystkie półmiski z rybami zabrano na trójkę do Teodora. Teodor nie pozwolił sobie ich odebrać.
# Boryczko rozejrzał się szybko po rewirze - z zadowoleniem stwierdził, że wśród kilkunastu par oczu zwróconych w jego stronę nie było tych niebieskich - dyskretnie skryły się za teczką tygodnika.
# "Zbój Madej" też coś wiedział. Z początku udawał, że się tym nie interesuje, zachowywał się wobec Romana tak jak zawsze: pociągał go za rękaw i powtarzał zamówienia lub prosił, by zechciał "rzucić okiem" na jego rewir. Ale raz, gdy się zeszli na rewirze i nic nie mieli do roboty, Robak pogłaskał swoją łysinę i zaczął namiętnie gryźć dolną wargę - znak, że ma coś ważnego do powiedzenia.
# Chwila milczenia. Romek uniósł się na łokciu, zaczął nerwowo mrugać okiem, wreszcie rzekł: - Ja myślę, że więcej, bo widzi pan, z tym okiem coś nie w porządku.
# Kierownik Stec wrócił z restauracji od Fornalskiego, sprawdził kasę, czy jest skręcona, schował kwity i zamknął szufladę. Przez chwilę myślał o czymś, wreszcie kiwnął głową, powiedział pannie Toli dobranoc i uśmiechając się sam do siebie, poszedł do garderoby po futro. Ubrawszy się, wstąpił do pokoju damskiego.
# Ale budzik jest dobry, co? Ilem razy go rzucał na podłogę i nic..., trzyma się kupy. Dobra marka, Jaz.
# I oto w tej chwili pociąg z Helą mknął przez zaśnieżone pola, a Roman szedł ostrożnie ulicą i unikał potrąceń, by nie uronić przedwcześnie ani odrobiny płynnej żałości, zapełniającej go aż po krtań i oczy.
# Gdzieś tam na "Sybirze", niby pająk w sieci ukryty, świdruje kelnerów wzrok starego Pancera - czują go nawet ci, w drugim końcu kawiarni, za czwartą ścianą z cegły. Niechby się już wyniósł stąd, a zrobiłoby się dobrze jak po wyrwaniu chorego zęba.
# Nie, "Kucyk" nie miał powodzenia wśród personelu, a najmniej u kelnerów. Jego motorkowo-pęcherzykowa ruchliwość i "cudeńka", jakie pokazywał przed gośćmi, budziły raczej wesołość niż podziw. Zrażony do kelnerów, zapędzał się do kuchni, ale tam znów gruby, wąsaty szef Balcer pokazywał mu kły: - Co pan tu chce, do rondli zaglądać i uczyć, jak sosy przyprawiać!?
# Stary Pancer, z rękami w kieszeniach spodni, stał oparty o biurko. Krótkie nogi założone jedna na drugą, dolna warga wysunięta, oczka zmrużone i patrzące tak samo jak o godzinie dwunastej spośród kolorowych wstęg i baloników koło drzwi kuchennych.
# Gdzieś tam w kłębach pary dojrzał i zapamiętał dziewczęcą twarz pomocnicy kawiarki, i znów oczy, tym razem bure, figlarne i wyłupiaste jak u wiewiórki. Czując, że mu gorąca fala zalewa policzki, niezgrabnie postawił szklankę na półce i nie widząc nic wycofał się na dużą salę. Szedł na oślep w kierunku swojego rewiru, szedł coraz wolniej, wreszcie potknął się o krzesło i stanął w miejscu.
# Na korytarzu ozwały się czyjeś kroki - Henek podniósł wskazujący palec do góry: - Ty, ja cię proszę, Adamowi nie mów nic, ona prosiła... i w ogóle nikomu...
# I znowu nic. Czarne, migotliwe oczy wpatrzyły się w Boryczkę, pyzata twarz i zadarty nos jakby napęczniały od krwi. "Smieszny jest ten baron i podobny do kogoś... aha, do parobka Wicka. A może to naprawdę Wicek, tylko przebrany i bogaty? E, nie, Wicek młodszy od niego." - Panie baronie, "London News" jest świeży - otwarł tytułową stronicą tygodnika.
# O godzinie ósmej wszyscy kelnerzy i pikole byli już na korytarzu kuchennym... Palmiak podchmielony i wesoły wychylił głowę przez okno: - Panowie!!! - wrzasnął - bufet wydawać!
# Henek opiekuńczo krążył w pobliżu. - Umiesz markować na kasie?
# Henek rozejrzał się wokoło i pewny, że nikt nie patrzy, zaczął tupać o podłogę i krzyczeć chrapliwym głosem: - Psiakrew! Smarkacz! Bijesz! Na kasie! Nie pamiętasz! Co robisz! Psiakrew! Smarkacz!
# Wszystko wydało mu się pozbawione tajemniczości, ograniczone czasem i przestrzenią, objęte umysłem i nieskomplikowane. Szedłby o zakład, że da radę obsłużyć wszystkie rewiry w kawiarni i jeszcze znajdzie trochę czasu na wypalenie papierosa. "Oni wszyscy są dzisiaj mętni - myślał patrząc na kierownika i kelnerów uwijających się po kawiarni jak mrówki w zburzonym mrowisku - przydałby się im jaki zastrzyk na uspokojenie".
# Roman klęczał na posadzce i szukał pieniędzy, które mu podczas inkasowania wypadły z ręki. Chodził tak na raczkach po całym rewirze, zaglądał pod foteliki i kanapy, ściereczka zwisała mu z kieszeni, włosy opadły na czoło - musiał je co chwila zarzucać w tył.
# On jest teraz na mnie zły, bo myśli, że ja mu to naumyślnie zrobiłem. Jakże bym ja śmiał...
# Około jedenastej śniadania się kończyły, zamawiano czarne kawy, herbaty i kapucyny. "Sybir" ział pustką - Wieliński i Bandera patrzyli przez okno na ulicę i wzrokiem odprowadzali przechodniów lub gapili się na gzymsy przyprószone śniegiem i ołowiany skrawek nieba, zabudowany kominami przyległych kamienic i zasiekami anten radiowych, sterczących wichrowato jak drewniane krzyże na starym cmentarzu .
# Roman dźwignął nowy ładunek podwieczorków i ruszył na salę. Tuż przed nim szedł Kantara - trzymał w rękach tak dużo tacek, że aby zrównoważyć ich ciężar, przechylił się w tył i łokieć oparł na brzuchu. Chcąc go pośpieszyć Roman krzyknął mu nad uchem: "prędzej!" - Kantara obejrzał się.
# Nikt się na to nie odezwał - Bandera zna się na tym lepiej od innych. Kiedyś powiedział tak: "I cóż z tego, że ci wszyscy filozofowie grzebią w książkach i tak dużo myślą? Co dokonali? Nic. A najzabawniejsze to, że zawsze wracają tam, skąd wyszli".
# Wieczorami spacerował wzdłuż kawiarni i zaglądał w okna pod firanki. Do interesu przychodził o szóstej rano, stawał w garderobie kawiarnianej, wyjmował zegarek i notes i zapisywał tych, którzy się spóźniali - już pierwszego dnia trafikantce i paru kelnerom nałożył grzywny po pięć złotych na cele dobroczynne.
# Mimo to Roman zbliżył się do stołu, oparł się o czyjeś krzesło i płaczliwym głosem zapytał: - Jaśnie pan redaktor życzył sobie "Kuriera"? Niech mi jaśnie pan wierzy, że nie ma ani jednego, wszystkie są zajęte, jak Boga kocham, że zajęte.
# Istotnie, w damskim pokoju aż syczało. Roman wpadł na swój rewir jak w nagalwanizowane pole. Ze wszech stron wołano płacić, trzymane w palcach banknoty powiewały w powietrzu, monety rzucane na marmur wpadały w kołujący, jednostajnie przyspieszony ruch lub toczyły się na brzeg stołu i tam, przytrzymane gwałtownym skokiem ręki, wydawały krótki fałszywy dźwięk .
# "Zostawiłam płaszcz przy piecu, żeby wysechł, i cały przód się przyżelił. Nie gniewaj się, bardzo cię proszę, przyślij mi dwadzieścia złotych, ja ci je oddam po pierwszym". Posłał jej dwadzieścia złotych, ale to go tak rozgoryczyło, że w tym samym dniu zapłacił czynsz, podatek i składki miesięczne do Związku, praczce dał zaległe piętnaście złotych i krawcowi spłacił dwie ostatnie raty za ubranie.

# %%
doc2
# Out:
# Litewska prokuratura poinformowała, że za podpaleniem sklepu IKEA w Wilnie i hali targowej w Warszawie w maju ubiegłego roku stał rosyjski wywiad. Przeciwko jednemu z podejrzanych skierowano właśnie akt oskarżenia, drugi jest w rękach polskich służb. Co wiadomo? Ustalenia litewskiej prokuratury: Śledczy zakończyli postępowanie w sprawie podpalenia sklepu IKEA w Wilnie, do którego doszło 9 maja ubiegłego roku. Prokurator generalny Litwy przekazał, że została ona zakwalifikowana jako "akt terroryzmu", a do sądu wpłynął akt oskarżenia przeciwko jednej osobie. "Dane zawarte w materiałach śledztwa przedprocesowego pozwalają przypuszczać, że czynów karalnych dokonał nieletni wówczas obywatel Ukrainy. Działał w interesie rosyjskich struktur wojskowych i służb bezpieczeństwa, w utworzonej wcześniej zorganizowanej grupie terrorystycznej, której celem było popełnianie przestępstw terrorystycznych na Litwie i na Łotwie wraz z innymi osobami" - czytamy w komunikacie. Podpalenie w Warszawie: Prokurator generalny Litwy podczas konferencji prasowej wyjaśnił, że bezpośrednimi sprawcami mają być dwaj obywatele Ukrainy w wieku poniżej 20 lat. Drugi z podejrzanych ma pozostać w rękach polskich organów ścigania w ramach współpracy obu krajów. Chodzi o jedną z dziewięciu osób zatrzymanych wiosną ubiegłego roku. Z informacji zdobytych przez litewskich śledczych wynika, że rosyjski wywiad ma stać także za podpaleniem hali targowej przy ul. Marywilskiej 44 w Warszawie.

# %%
dict1 = {"NOUN": 0, "VERB": 0, "ADP": 0, "CCONJ ": 0}
for t in doc1:
    if t.pos_ in dict1:
        dict1[t.pos_] += 1

dict1
# Out:
# {'NOUN': 406, 'VERB': 272, 'ADP': 212, 'CCONJ ': 0}

# %%
dict2 = {"NOUN": 0, "VERB": 0, "ADP": 0, "CCONJ ": 0}
for t in doc2:
    if t.pos_ in dict2:
        dict2[t.pos_] += 1
        
dict2
# Out:
# {'NOUN': 65, 'VERB': 22, 'ADP': 33, 'CCONJ ': 0}

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(dict1.keys(), dict1.values())
# Out:
# <BarContainer object of 4 artists>

# %%
plt.bar(dict2.keys(), dict2.values())
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# # Zadanie 5
# Dla wczytanych w zadaniu 4 tekstów
#
# Oblicz proporcję czasowników (używając tagów UD),
#
# *  Na podstawie wyników i wykresu oszacuj gatunek do którego należy tekst

# %%
print("Stosunek czasowników do rzeczowników: ", dict1["VERB"]/dict1["NOUN"])
print("Proporcja czasowników: ", dict1["VERB"]/sum(dict1.values()))
print("Proporcja rzeczowników: ", dict1["NOUN"]/sum(dict1.values()))
# Out:
# Stosunek czasowników do rzeczowników:  0.6699507389162561
# Proporcja czasowników:  0.3056179775280899
# Proporcja rzeczowników:  0.45617977528089887

# %%
print("Stosunek czasowników do rzeczowników: ", dict2["VERB"]/dict1["NOUN"])
print("Proporcja czasowników: ", dict2["VERB"]/sum(dict2.values()))
print("Proporcja rzeczowników: ", dict2["NOUN"]/sum(dict2.values()))
# Out:
# Stosunek czasowników do rzeczowników:  0.054187192118226604
# Proporcja czasowników:  0.18333333333333332
# Proporcja rzeczowników:  0.5416666666666666

# %% [markdown]
# Do którego gatunku nalezy tekst ?
